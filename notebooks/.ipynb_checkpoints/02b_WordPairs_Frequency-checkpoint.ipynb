# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import collections

# %%
kroeber = pd.read_excel(f'../data/Kroeber texts.xlsx',None)
reichard = pd.read_excel(f'../data/Reichard texts.xlsx',None)
teeter = pd.read_excel(f'../data/Teeter texts.xlsx',None)
# Out:
# /Users/leonjdaeim/opt/miniconda3/envs/EDA/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# crow = wiyotData['Crow']
# skunk = wiyotData['Crow']
# pelican = wiyotData['Pelican']

# %%
def processLine(x):
    try:
        x = '\t'.join(x.dropna()).split('\t')
        return x
    except:
        return None
    
getlowercase = lambda x: x if x.isupper() else x.lower()    

def getWordPairs(phrase):
    wordpairlist = []
    for i in range(0,len(phrase)-1):
        wordpairlist.append('|'.join([phrase[i],phrase[i+1]]))
    return wordpairlist

def countFrequencyWordPairs(listofwordpairs):
    try:
        return collections.Counter(listofwordpairs[:])
    except:
        return None

# %%
def getWordPairsFromText(data):
    try:
        storyWordPairs = []
        for i in range(0,len(data),3):
            wiyotPhrase = data.iloc[i]
            englishPhrase = data.iloc[i+1]
            ####
            wiyotPhrase = processLine(wiyotPhrase)
            ### Do some extra processing to the english phrase
            englishPhrase = processLine(englishPhrase)
            englishPhrase = [getlowercase(x) for x in englishPhrase]
            ###
            wps = getWordPairs(englishPhrase)
            storyWordPairs.append(wps)    
        storyWordPairs = sum(storyWordPairs,[])    
        return storyWordPairs
    except:
        return []

# %%
def getAllWordPairsFromAuthor(author):
    stories_dictionary = dict()
    for story, text in author.items():
        stories_dictionary[story] = getWordPairsFromText(text)
    return sum(stories_dictionary.values(),[])

# %%
kroeber_wordpairs = getAllWordPairsFromAuthor(kroeber)
reichard_wordpairs = getAllWordPairsFromAuthor(reichard)
teeter_wordpairs = getAllWordPairsFromAuthor(teeter)

# %%
import random

# %%
# Out:
# True

# %%
import time
for x in range (0,5):  
    b = "Loading" + "." * x
    print (b, end="\r")
    time.sleep(1)
# Out:
# Loading....

# %%
getWordPairsFromText(reichard['13. He-Who-Was-Dug-Up'])
# Out:
# ['once.upon.a.time|3POSS',
#  '3POSS|INCH',
#  'INCH|dig.bulbs',
#  'dig.bulbs|3SBJ.INDF',
#  '3SBJ.INDF|indian.potato.',
#  'INCH|tell',
#  'tell|TH.IMPL',
#  'TH.IMPL|INST.IMPL[3SBJ.PASS]',
#  'INST.IMPL[3SBJ.PASS]|be.one',
#  'be.one|EMP',
#  'EMP|have.leaves',
#  'have.leaves|NMLZ',
#  'PROH|touch',
#  'touch|3OBJ<TH.NEG>[2SBJ.IMP].',
#  '3OBJ<TH.NEG>[2SBJ.IMP].|DEM',
#  'DEM.DIST|be.two',
#  'be.two|EMP',
#  'EMP|have.leaves',
#  'have.leaves|NMLZ.',
#  'NMLZ.|DEM',
#  'DEM|PROG',
#  'PROG|dig.bulbs',
#  'dig.bulbs|3SBJ.IMPL',
#  'bay|cross.',
#  'cross.|UNK',
#  'UNK|LOC',
#  'LOC|PROG',
#  'PROG|go.to',
#  'go.to|gather.nuts',
#  'gather.nuts|TH.PASS',
#  'TH.PASS|3SBJ.PASS.',
#  'DEM|PROG',
#  'PROG|scold',
#  'scold|3OBJ<TH.SBJV>[3SBJ]',
#  'PROH|touch',
#  'touch|3OBJ<TH.NEG>[2SBJ.IMP].',
#  '3OBJ<TH.NEG>[2SBJ.IMP].|3NEG',
#  '3NEG|touch',
#  'touch|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  'sometime|PROG',
#  'PROG|happen[nmlz]',
#  'happen[nmlz]|ITER',
#  'ITER|INCH',
#  'INCH|all',
#  'all|go.off[3sbj].',
#  'PST|think',
#  'think|3SBJ.DEF',
#  '3SBJ.DEF|try',
#  'try|3OBJ',
#  '3OBJ|1SBJ',
#  '1SBJ|AFF.',
#  'INCH|dig.hole.in.ground',
#  'dig.hole.in.ground|3OBJ',
#  '3OBJ|NMLZ',
#  'NMLZ|go.into',
#  'go.into|EMP',
#  'EMP|put.into.ground',
#  'put.into.ground|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  'hear.person|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  '3SBJ.DEF|child',
#  'child|3POSS',
#  '3POSS|cry',
#  'cry|NMLZ',
#  'NMLZ|3POSS.',
#  'ITER|pull',
#  'pull|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  '3SBJ.DEF.|child',
#  'child|PST',
#  'PST|come.out.on.end.of[3sbj].',
#  'DEM.DIST|old.woman',
#  'old.woman|PST',
#  'PST|think',
#  'think|3SBJ.DEF',
#  '3SBJ.DEF|2POSS',
#  '2POSS|be.large',
#  'be.large|see[1sbj].',
#  'INCH|say.to',
#  'say.to|TH.IMPL',
#  'TH.IMPL|INST.IMPL[3SBJ.PASS]',
#  'PROH|touch',
#  'touch|3OBJ<TH.NEG>[2SBJ.IMP].',
#  '3OBJ<TH.NEG>[2SBJ.IMP].|across',
#  'across|carry',
#  'carry|3SBJ.INDF.',
#  'PST|think',
#  'think|3SBJ.DEF',
#  '3SBJ.DEF|POSS',
#  'POSS|raise',
#  'raise|by.hand',
#  'by.hand|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  '3SBJ.DEF|AFF.',
#  'EMPH|INCH',
#  'INCH|grow.up',
#  'grow.up|3SBJ.DEF.',
#  '3SBJ.DEF.|INCH',
#  'INCH|go.about',
#  'go.about|3SBJ.DEF.',
#  '3SBJ.DEF.|DEM.DIST',
#  'INCH|here.and.there',
#  'here.and.there|run',
#  'run|3SBJ.DEF.',
#  '3SBJ.DEF.|suddenly',
#  'suddenly|ITER',
#  'ITER|come',
#  'come|3SBJ.DEF',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '3SBJ.DEF|something',
#  'something|see',
#  'see|TH<TH.N.IND>SBJV',
#  'TH<TH.N.IND>SBJV|1SBJ.SBJV.',
#  'DEM.PROX|old.woman',
#  'old.woman|out',
#  'out|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|ITER',
#  'ITER|come.in',
#  'come.in|3SBJ.DEF.',
#  'punch.at|cl.cylindrical',
#  'cl.cylindrical|3SBJ.INDF[NMLZ]',
#  '3SBJ.INDF[NMLZ]|go.in',
#  'go.in|carry',
#  'carry|3SBJ.DEF.',
#  'INCH|string.bow',
#  'string.bow|3SBJ.DEF',
#  '3SBJ.DEF|arrow',
#  'arrow|in.secret',
#  'in.secret|make.arrow',
#  'make.arrow|3SBJ.DEF.',
#  'PST|say.to',
#  'say.to|3OBJ',
#  '3OBJ|INST',
#  'INST|3SBJ.DEF',
#  'HORT|around',
#  'around|ITER',
#  'ITER|go.to',
#  'go.to|look.for',
#  'look.for|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  'PST|from.behind',
#  'from.behind|hand.over',
#  'hand.over|3OBJ',
#  '3OBJ|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  '3NEG|PFV',
#  'PFV|be.long.time',
#  'be.long.time|NMLZ.INF',
#  'NMLZ.INF|PST',
#  'PST|ITER',
#  'ITER|come',
#  'come|3SBJ.DEF',
#  '3SBJ.DEF|cotton.tail',
#  'PST|bring',
#  'bring|3SBJ.DEF.',
#  '3SBJ.DEF.|DEM',
#  'DEM|PROG',
#  'PROG|do.so',
#  'do.so|3SBJ.DEF.',
#  'PROG|go.around',
#  'go.around|3SBJ.DEF.',
#  '3SBJ.DEF.|suddenly',
#  'suddenly|ITER',
#  'ITER|come',
#  'come|3SBJ.DEF',
#  '3SBJ.DEF|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  'something|see',
#  'see|TH.SBJV',
#  'TH.SBJV|1SBJ.SBJV.',
#  '1SBJ.SBJV.|old.woman',
#  'old.woman|deer',
#  'deer|DUB',
#  'PST|shoot',
#  'shoot|3OBJ',
#  '3OBJ|2SBJ',
#  '2SBJ|WARN.',
#  'WARN.|PST',
#  'PST|ITER',
#  'ITER|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|DEM',
#  'then|ITER',
#  'ITER|come',
#  'come|3SBJ.DEF',
#  '3SBJ.DEF|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '3SBJ.DEF|PST',
#  'PST|kill',
#  'kill|3OBJ[1SBJ]',
#  'NEG.EMPH|1NEG',
#  '1NEG|bring',
#  'bring|NEG[1SBJ]',
#  'NEG[1SBJ]|very',
#  'very|be.heavy',
#  'be.heavy|3SBJ.STV.',
#  'PST|all',
#  'all|go.off[3sbj]',
#  'go.off[3sbj]|go.to',
#  'go.to|EMP',
#  'EMP|cl.elk.meat',
#  'cl.elk.meat|carry.meat.back.to.camp',
#  'carry.meat.back.to.camp|NMLZ.INF.',
#  'ITER|all',
#  'all|go.off[3sbj].',
#  'go.off[3sbj].|go.to',
#  'go.to|3NEG',
#  '3NEG|be.much',
#  'be.much|be.long.time',
#  'be.long.time|NMLZ.INF',
#  'NMLZ.INF|linnet',
#  'PST|ITER',
#  'ITER|come',
#  'come|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|say.to',
#  'say.to|3OBJ',
#  '3OBJ|INST',
#  'INST|3SBJ.DEF',
#  '3POSS|nephew',
#  'nephew|SUB',
#  'SUB|3POSS',
#  '3POSS|down.on.beach',
#  'PROG|play',
#  'play|play<th.pass>[3sbj.pass]',
#  'play<th.pass>[3sbj.pass]|shark.',
#  'PST|DEM.DIST',
#  'DEM.DIST|be.light[nmlz]',
#  'be.light[nmlz]|linnet',
#  'linnet|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '3SBJ.DEF|HORT',
#  'go.to|all',
#  'all|witness',
#  'witness|3SBJ.INDF',
#  '3SBJ.INDF|HORT.',
#  'HORT.|PST',
#  'PST|go[3sbj].',
#  'PROG|on.arrival',
#  'on.arrival|come',
#  'come|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|on.arrival',
#  'on.arrival|see',
#  'see|TH.PASS[3SBJ.PASS]',
#  '3POSS|INCH',
#  'INCH|play',
#  'play|NMLZ.INF.',
#  'NMLZ.INF.|PROG',
#  'PROG|ITER',
#  'ITER|go.up[3sbj]',
#  'go.up[3sbj]|PST',
#  'PST|go.down',
#  'go.down|3SBJ.INDF',
#  'PST|grasp',
#  'grasp|tail',
#  'tail|by.hand',
#  'by.hand|3POSS.',
#  '3POSS.|(PST',
#  '(PST|)go.up',
#  ')go.up|by.hand',
#  'by.hand|CAUS',
#  'CAUS|3SBJ.INDF',
#  'on.beach|way.up',
#  'way.up|put',
#  'put|CAUS',
#  'CAUS|3SBJ.INDF.',
#  '3SBJ.INDF.|ITER',
#  'ITER|go.down',
#  'go.down|3SBJ.DEF.',
#  'water|PST',
#  'PST|go.to',
#  'go.to|almost',
#  'almost|be.on.verge.of',
#  'be.on.verge.of|ITER',
#  'ITER|come',
#  'come|3SBJ.DEF.',
#  '3SBJ.DEF.|DEM',
#  'where|ITER',
#  'ITER|from.behind',
#  'from.behind|catch<emp>[3sbj].',
#  'catch<emp>[3sbj].|EMPH',
#  'EMPH|ITER',
#  'ITER|go',
#  'go|3SBJ.DEF.',
#  'DEM.PROX|CONT',
#  'CONT|where',
#  'where|be.small',
#  'be.small|be.long.time',
#  'be.long.time|NMLZ.INF',
#  'NMLZ.INF|ITER',
#  'ITER|come.up',
#  'come.up|3SBJ.DEF.',
#  'PFV|ITER',
#  'ITER|grasp<3sbj.pass>.',
#  'grasp<3sbj.pass>.|ITER',
#  'ITER|go.up',
#  'go.up|by.hand',
#  'by.hand|CAUS',
#  'CAUS|3SBJ.INDF',
#  'on.beach|way.up',
#  'way.up|put',
#  'put|CAUS',
#  'CAUS|3SBJ.INDF[PASS].',
#  '3SBJ.INDF[PASS].|ITER',
#  'ITER|go.down',
#  'go.down|3SBJ.DEF.',
#  'where|from.behind',
#  'from.behind|catch[3sbj.pass].',
#  'catch[3sbj.pass].|EMPH',
#  'EMPH|ITER',
#  'ITER|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|again',
#  'PST|ITER',
#  'ITER|go.up',
#  'go.up|3SBJ.DEF.',
#  '3SBJ.DEF.|linnet',
#  'linnet|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  'go.to|please',
#  'please|grab',
#  'grab|3OBJ',
#  '3OBJ|3SBJ.IMP.',
#  '3SBJ.IMP.|he.who.was.dug.up',
#  'PST|go.down',
#  'go.down|3SBJ.DEF',
#  '3SBJ.DEF|PFV',
#  'PFV|catch',
#  'catch|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  'PST|go.up',
#  'go.up|by.hand',
#  'by.hand|CAUS',
#  'CAUS|3SBJ.DEF.',
#  '3SBJ.DEF.|on.beach',
#  'on.beach|way.up',
#  'way.up|put',
#  'put|CAUS',
#  'CAUS|3SBJ.INDF.',
#  'ITER|go.down',
#  'go.down|3SBJ.DEF.',
#  '3SBJ.DEF.|go.to',
#  'go.to|DEM.DIST',
#  'DEM.DIST|from.behind',
#  'from.behind|grasp<emp>.',
#  'PROG|at.last',
#  'at.last|ITER',
#  'ITER|go.down',
#  'go.down|3SBJ.DEF.',
#  '3SBJ.DEF.|NEG.EMPH',
#  'NEG.EMPH|be.long.time',
#  'be.long.time|NMLZ.INF',
#  'PROG|ITER',
#  'ITER|come.up',
#  'come.up|3SBJ.DEF.',
#  '3SBJ.DEF.|ITER',
#  'ITER|grab[3sbj]',
#  'grab[3sbj]|ITER',
#  'ITER|go.up',
#  'go.up|carry',
#  'carry|3SBJ.INDF',
#  'east|way.up',
#  'way.up|put',
#  'put|CAUS',
#  'CAUS|3SBJ.INDF.',
#  '3SBJ.INDF.|ITER',
#  'ITER|go.down',
#  'go.down|3SBJ.DEF.',
#  'go.to|ITER',
#  'ITER|from.behind',
#  'from.behind|grab<emp>[3sbj].',
#  'grab<emp>[3sbj].|ITER',
#  'ITER|go.down',
#  'go.down|3SBJ.DEF.',
#  'he.who.was.dug.up|PROG',
#  'PROG|carry',
#  'carry|3SBJ.DEF.',
#  'EMPH|INCH',
#  'INCH|be.pulled.down[3sbj.pass].',
#  'be.pulled.down[3sbj.pass].|go.down',
#  'go.down|take',
#  'take|3SBJ.INDF.',
#  'PST|all',
#  'all|think',
#  'think|3SBJ.INDF',
#  '3SBJ.INDF|PROG',
#  'PROG|PST',
#  'PST|die[3sbj]',
#  'here.and.there|hear.news',
#  'hear.news|TH.IMPL',
#  'TH.IMPL|3SBJ.IMPL.',
#  '3SBJ.IMPL.|sometime',
#  'sometime|PROG',
#  'PROG|happen[nmlz]',
#  'go.to|3NEG',
#  '3NEG|be.much',
#  'be.much|be.long.time',
#  'be.long.time|NMLZ.INF',
#  'NMLZ.INF|ITER',
#  'ITER|come',
#  'come|3SBJ.DEF.',
#  'DEM.PROX|old.woman',
#  'old.woman|3NEG',
#  '3NEG|recognize',
#  'recognize|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  'ITER|come[1sbj]',
#  'come[1sbj]|west',
#  'west|EMP',
#  'EMP|on.that.side',
#  'on.that.side|way.down',
#  'way.down|come[1sbj]',
#  'DEM|around',
#  'around|dwell[3sbj]',
#  'dwell[3sbj]|1SG',
#  '1SG|father',
#  'father|be.good',
#  'be.good|EMP',
#  'EMP|treat',
#  'treat|3SBJ.DEF',
#  'DEM|1SG',
#  '1SG|in.secret',
#  'in.secret|UNK',
#  'UNK|1OBJ',
#  '1OBJ|3SBJ.DEF',
#  '3SBJ.DEF|see',
#  'see|1SBJ.',
#  'shark[poss]|value',
#  'value|NMLZ.P',
#  'NMLZ.P|give',
#  'give|3SBJ.INDF',
#  'go.to|kidnap',
#  'kidnap|NMLZ.INF',
#  'NMLZ.INF|3POSS.',
#  '3POSS.|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '3SBJ.DEF|ITER',
#  'ITER|go',
#  'go|3SBJ.DEF',
#  'AFF|PST',
#  'PST|ITER',
#  'ITER|go',
#  'go|3OBJ',
#  '3OBJ|2SBJ',
#  '2SBJ|2POSS',
#  '2POSS|grandmother.',
#  'grandmother.|linnet',
#  'be.nice|INCH',
#  'INCH|make',
#  'make|REFL',
#  'REFL|3SBJ.DEF',
#  '3SBJ.DEF|hair',
#  'hair|3POSS',
#  '3POSS|PROG',
#  'PROG|pull.out.hair',
#  'pull.out.hair|3SBJ.DEF.',
#  '3POSS|hair',
#  'hair|3POSS',
#  '3POSS|linnet',
#  'linnet|PST',
#  'PST|put.in.hair',
#  'put.in.hair|3SBJ.DEF',
#  'around|EMP',
#  'EMP|be.head',
#  'be.head|SUB',
#  'SUB|NMLZ.',
#  'NMLZ.|DEM.PROX',
#  'DEM.PROX|old.woman',
#  'old.woman|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  'PROG|PROH',
#  'PROH|say.to',
#  'say.to|TH.IMPL',
#  'TH.IMPL|INST.IMPL',
#  'INST.IMPL|NEG[3SBJ.PASS]',
#  'here.and.there|wander',
#  'wander|3SBJ.IMP.',
#  '3SBJ.IMP.|DEM.PROX',
#  'DEM.PROX|old.woman',
#  'old.woman|acorn',
#  'PROG|go.to',
#  'go.to|gather.acorns',
#  'gather.acorns|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  '3SBJ.DEF.|rather.early',
#  'PROG|in.vain',
#  'in.vain|EMP',
#  'EMP|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|NEG.EMPH',
#  'NEG.EMPH|see',
#  'see|3SBJ.INDF',
#  '3SBJ.INDF|acorn',
#  'PROG|all',
#  'all|go.up',
#  'go.up|3SBJ<TH.PASS>PASS(UNK).',
#  '3SBJ<TH.PASS>PASS(UNK).|where',
#  'where|relating.to',
#  'relating.to|DUB',
#  'DUB|person',
#  'where|INT',
#  'INT|come.from',
#  'come.from|3SBJ.DEF.',
#  '3SBJ.DEF.|linnet',
#  'linnet|PST',
#  'PST|think',
#  'think|3SBJ.DEF',
#  'go.to|watch',
#  'watch|3OBJ[1SBJ]',
#  '3OBJ[1SBJ]|AFF.',
#  'AFF.|rather.early',
#  'rather.early|PST',
#  'PST|go',
#  'go|3SBJ.DEF.',
#  'PST|PROG',
#  'PROG|on.arrival',
#  'on.arrival|come',
#  'come|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|on.arrival',
#  'on.arrival|see',
#  'see|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  'girl|3POSS',
#  '3POSS|DEF',
#  'DEF|be.two',
#  'be.two|EMP',
#  'EMP|sit',
#  'sit|NMLZ.INF',
#  'NMLZ.INF|3POSS.',
#  'PST|on.arrival',
#  'on.arrival|speak.to',
#  'speak.to|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|ask',
#  'ask|3OBJ',
#  '3OBJ|INST',
#  'INST|3SBJ.DEF',
#  'where|relating.to',
#  'relating.to|INT',
#  'INT|around',
#  'around|come.from',
#  'come.from|2SBJ<N.IND>SBJV?',
#  '2SBJ<N.IND>SBJV?|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '1PL|ADVS',
#  'ADVS|from',
#  'from|south',
#  'south|where',
#  'where|1POSS',
#  '1POSS|down',
#  'down|go',
#  'go|1SBJ.PL.',
#  '2PL|EMPH',
#  'EMPH|be.nice',
#  'be.nice|EMP',
#  'EMP|appear',
#  'appear|2SBJ.PL',
#  '2SBJ.PL|EMP',
#  'EMP|2PL.',
#  '1SG|son.of.sister.of.mother',
#  'son.of.sister.of.mother|also',
#  'also|surely',
#  'surely|be.nice',
#  'be.nice|EMP',
#  'EMP|appear[3sbj].',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '3SBJ.DEF|yes.',
#  'yes.|girl',
#  'girl|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  'sheldrake|also',
#  'also|surely',
#  'surely|be.nice',
#  'be.nice|EMP',
#  'EMP|appear[3sbj].',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '3SBJ.DEF|girl',
#  'girl|ITER',
#  'ITER|go[1sbj]',
#  'go[1sbj]|AFF.',
#  'AFF.|linnet',
#  'PST|ITER',
#  'ITER|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|PROG',
#  'PROG|ITER',
#  'ITER|come',
#  'come|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  'now|PST',
#  'PST|EMP',
#  'EMP|see',
#  'see|1SBJ',
#  '1SBJ|way.up',
#  'way.up|go.up',
#  'go.up|EMP',
#  'EMP|dwell[3sbj]',
#  'girl|surely',
#  'surely|DEM.PROX',
#  'DEM.PROX|EMP',
#  'EMP|unshelled.acorn',
#  'PROG|go.to',
#  'go.to|come.from',
#  'come.from|gather',
#  'gather|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|speak.to',
#  'speak.to|3OBJ[3SBJ.DEF].',
#  'now|3PL',
#  '3PL|PST',
#  'PST|ITER',
#  'ITER|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|DEM.DIST',
#  'DEM.DIST|be.light[nmlz]',
#  'linnet|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '3SBJ.DEF|DEM',
#  'DEM|AFF',
#  'AFF|go.to',
#  'go.to|ITER',
#  'ITER|go[1sbj].',
#  '3POSS|nephew',
#  'nephew|SUB',
#  'SUB|3POSS',
#  '3POSS|PST',
#  'PST|accompany',
#  'accompany|3SBJ.DEF.',
#  'PROG|on.arrival',
#  'on.arrival|come[3sbj].',
#  'come[3sbj].|ITER',
#  'ITER|on.arrival',
#  'on.arrival|see',
#  'see|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  'DEM.DIST|girl',
#  'girl|3PL.',
#  '3PL.|linnet',
#  'linnet|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '3SBJ.DEF|1POSS',
#  '1POSS|nephew',
#  'sit.dim[3sbj].|DEM',
#  'DEM|yesterday',
#  'yesterday|DEM.PROX',
#  'DEM.PROX|mention',
#  'mention|2OBJ[1SBJ].',
#  'ITER|be.on.verge.of',
#  'be.on.verge.of|go.off[3sbj].',
#  'go.off[3sbj].|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  'PST|accompany',
#  'accompany|3SBJ.DEF',
#  '3SBJ.DEF|AFF.',
#  'AFF.|PST',
#  'PST|ITER',
#  'ITER|go',
#  'go|3SBJ.DEF',
#  '3SBJ.DEF|3PL',
#  'he.who.was.dug.up|PST',
#  'PST|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|girl',
#  'girl|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  'ITER|all',
#  'all|carry.dim',
#  'carry.dim|1SBJ',
#  '1SBJ|AFF',
#  'AFF|tan.oak',
#  'tan.oak|cl.tree.',
#  'PST|ITER',
#  'ITER|all',
#  'all|carry.dim',
#  'carry.dim|3SBJ.DEF',
#  '3SBJ.DEF|also.',
#  'also.|PROG',
#  'PROG|on.arrival',
#  'on.arrival|ITER',
#  'ITER|come[3sbj].',
#  'upon.arrival|see',
#  'see|TH.PASS[3SBJ]',
#  'TH.PASS[3SBJ]|DEF',
#  'DEF|play.stick.game',
#  'play.stick.game|TH.PASS',
#  'TH.PASS|NMLZ.P.',
#  'PST|say.to',
#  'say.to|TH.IMPL',
#  'TH.IMPL|INST.IMPL[3SBJ.PASS]',
#  'INST.IMPL[3SBJ.PASS]|play.stick.game',
#  'play.stick.game|3OBJ',
#  '3OBJ|2SBJ.HORT',
#  'AFF.|he.who.was.dug.up',
#  'he.who.was.dug.up|INCH',
#  'INCH|play.stick.game',
#  'play.stick.game|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  'PST|match',
#  'match|3SBJ.DEF',
#  '3SBJ.DEF|thunder.',
#  'thunder.|PST',
#  'PST|strike',
#  'strike|throw',
#  'throw|TH.PASS',
#  'TH.PASS|3SBJ.PASS.',
#  'win|3SBJ.DEF.',
#  '3SBJ.DEF.|again.and.again',
#  'again.and.again|PST',
#  'PST|ITER',
#  'ITER|INCH',
#  'INCH|play.stick.game',
#  'play.stick.game|3SBJ.INDF.',
#  'earthquake|match',
#  'match|3SBJ.DEF.',
#  '3SBJ.DEF.|ITER',
#  'ITER|strike',
#  'strike|throw',
#  'throw|TH.PASS',
#  'TH.PASS|3SBJ.PASS.',
#  'ITER|win',
#  'win|3SBJ.DEF.']

# %%
# Out:
# ['long.ago|3SBJ.DEF',
#  '3SBJ.DEF|girl',
#  'girl|be.one',
#  'be.one|EMP',
#  'EMP|CESS',
#  'CESS|grow',
#  'grow|REFL',
#  'REFL|3SBJ.DEF.',
#  'DEM|INCH',
#  'INCH|do.so',
#  'do.so|3SBJ.DEF',
#  '3SBJ.DEF|grass',
#  'PROG|go.about',
#  'go.about|NMLZ',
#  'NMLZ|SUB',
#  'SUB|3POSS',
#  '3POSS|stick',
#  'stick|around',
#  'around|carry',
#  'carry|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  'stick|around',
#  'around|hit',
#  'hit|EMP',
#  'EMP|cl.hairlike',
#  'cl.hairlike|move.aside',
#  'move.aside|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  '3POSS|scare',
#  'scare|NMLZ.INF',
#  'NMLZ.INF|SUB',
#  'SUB|3POSS',
#  '3POSS|CESS',
#  'CESS|PROB',
#  'PROB|see',
#  'see|1SBJ',
#  'around|drag',
#  'drag|NMLZ.P.',
#  'NMLZ.P.|DEM',
#  'DEM|around',
#  'around|do.so',
#  'do.so|3SBJ.DEF.',
#  'some.time|when.nmlz',
#  'when.nmlz|PROG',
#  'PROG|happen',
#  'PST|go.to',
#  'go.to|gather.heracleum.lanatum',
#  'gather.heracleum.lanatum|3SBJ.INDF.',
#  'PST|PROG',
#  'PROG|on.arrival',
#  'on.arrival|land',
#  'land|3SBJ.STV.',
#  'INCH|gather.heracleum.lanatum',
#  'gather.heracleum.lanatum|3SBJ.INDF.',
#  'soon|INCH',
#  'INCH|carry.load.on.back.dim',
#  'carry.load.on.back.dim|affect',
#  'affect|TH.IMPL[3SBJ].',
#  'PST|call.in.woods',
#  'call.in.woods|TH.IMPL[3SBJ]',
#  'TH.IMPL[3SBJ]|DEM.DIST',
#  'DEM.DIST|girl.',
#  'PST|tell',
#  'tell|TH.IMPL',
#  'TH.IMPL|INST.IMPL[3SBJ.PASS]',
#  'INST.IMPL[3SBJ.PASS]|ITER',
#  'ITER|INCH',
#  'INCH|travel[1sbj.pl]',
#  'travel[1sbj.pl]|AFF.',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '3SBJ.DEF|all.right.',
#  'all.right.|ITER',
#  'ITER|INCH',
#  'INCH|EMP',
#  'EMP|go[3sbj]',
#  'go[3sbj]|AFF.',
#  'PST|think',
#  'think|3SBJ.DEF',
#  '3SBJ.DEF|INCH',
#  'INCH|carry.load[1sbj]',
#  'carry.load[1sbj]|AFF.',
#  'in.vain|pull.with.hands',
#  'pull.with.hands|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  '3POSS|DEM.PROX',
#  'DEM.PROX|carry.load.on.back.dim',
#  'carry.load.on.back.dim|NMLZ.INF',
#  'NMLZ.INF|SUB',
#  'SUB|3POSS.',
#  'then|ITER',
#  'ITER|be.up',
#  'be.up|stand',
#  'stand|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|look.at',
#  'look.at|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  'PST|EMP',
#  'EMP|see',
#  'see|3SBJ.DEF',
#  '3SBJ.DEF|INDF',
#  'INDF|drag',
#  'drag|NMLZ.P',
#  '3POSS|PROG',
#  'PROG|lie',
#  'lie|3SBJ.STV.',
#  '3SBJ.STV.|surely',
#  'around|on.the.move',
#  'on.the.move|grasp',
#  'grasp|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  '3SBJ.DEF.|DEM',
#  '3NEG|be.up',
#  'be.up|carry.load.on.back',
#  'carry.load.on.back|3SBJ.DEF.',
#  'PST|tell',
#  'tell|TH.IMPL',
#  'TH.IMPL|INST.IMPL[3SBJ.PASS]',
#  'INST.IMPL[3SBJ.PASS]|AFF',
#  'INCH|accompany',
#  'accompany|2SBJ.IMP.',
#  '2SBJ.IMP.|already',
#  'already|see',
#  'see|2OBJ[1SBJ]',
#  'DEM|2POSS',
#  '2POSS|PROG',
#  'PROG|do.so',
#  'do.so|2SBJ.SBJV',
#  'when.2sbj|PROG',
#  'PROG|go.about',
#  'go.about|2SBJ.SBJV',
#  'stick|2POSS',
#  '2POSS|around',
#  'around|carry',
#  'carry|3OBJ',
#  '3OBJ|2SBJ.SBJV',
#  '2POSS|around',
#  'around|hit',
#  'hit|EMP',
#  'EMP|cl.hairlike',
#  'cl.hairlike|move.aside',
#  'move.aside|3OBJ',
#  '3OBJ|2SBJ.SBJV.',
#  '2SBJ.SBJV.|now',
#  'DEM|go.to',
#  'go.to|come.to.get',
#  'come.to.get|2OBJ[1SBJ].',
#  '2OBJ[1SBJ].|PST',
#  'PST|over',
#  'over|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|water',
#  'go.to|on.arrival',
#  'on.arrival|PROG',
#  'PROG|on.arrival',
#  'on.arrival|go.through.enclosure',
#  'go.through.enclosure|3SBJ.DEF.',
#  'DEM.PROX|also',
#  'also|around',
#  'around|feel.like',
#  'feel.like|3SBJ.DEF',
#  'PST|ITER',
#  'ITER|feel.like',
#  'feel.like|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|on.arrival',
#  'on.arrival|see',
#  'see|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  '3POSS|inside.',
#  'inside.|PST',
#  'PST|on.arrival',
#  'on.arrival|go.through.enclosure',
#  'go.through.enclosure|3SBJ.DEF.',
#  'upon.arrival|see',
#  'see|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  'go.down.into|at.end.of',
#  'at.end.of|do.with.face',
#  'do.with.face|lie',
#  'lie|3SBJ.STV.',
#  '3SBJ.STV.|have.sense',
#  'have.sense|NMLZ.A',
#  'NMLZ.A|3PL',
#  'only|PROG',
#  'PROG|PL',
#  'PL|be.at.home[3sbj].',
#  'soon|PST',
#  'PST|hear.noise',
#  'hear.noise|3SBJ.DEF',
#  '3SBJ.DEF|3POSS',
#  '3POSS|creak',
#  'creak|NMLZ.INF.',
#  'DEM.DIST|woods',
#  'woods|PFV',
#  'PFV|go.about',
#  'go.about|3SBJ.DEF',
#  '3SBJ.DEF|ITER',
#  'ITER|come',
#  'come|3SBJ.DEF.',
#  'PST|EMP',
#  'EMP|see',
#  'see|3SBJ.DEF',
#  '3SBJ.DEF|ITER',
#  'ITER|go.through.enclosure',
#  'go.through.enclosure|NMLZ.INF',
#  'NMLZ.INF|SUB',
#  'SUB|3POSS.',
#  'DEM|PST',
#  'PST|ITER',
#  'ITER|each',
#  'each|lie',
#  'lie|3SBJ.STV.',
#  '3SBJ.STV.|soon',
#  'PST|ITER',
#  'ITER|hear.noise',
#  'hear.noise|3SBJ.DEF',
#  '3SBJ.DEF|DEM.DIST',
#  'DEM.DIST|creak',
#  'creak|NMLZ.INF.',
#  'AFF|then',
#  'then|ITER',
#  'ITER|come',
#  'come|3SBJ.DEF',
#  '3SBJ.DEF|DEM.DIST',
#  'DEM.DIST|PFV',
#  'PFV|suck',
#  'suck|eat',
#  'eat|NMLZ.A.',
#  'PST|EMP',
#  'EMP|see',
#  'see|3SBJ.DEF',
#  '3SBJ.DEF|PST',
#  'PST|ITER',
#  'ITER|INDF',
#  'INDF|vomit',
#  'vomit|NMLZ.INF',
#  'NMLZ.INF|SUB',
#  'SUB|3POSS',
#  'people.|PST',
#  'PST|think',
#  'think|3SBJ.DEF',
#  '3SBJ.DEF|DEM',
#  'DEM|DEM',
#  'DEM|EMPH',
#  'DEF|suck',
#  'suck|eat',
#  'eat|NMLZ.A.',
#  'NMLZ.A.|DEM',
#  'DEM|INCH',
#  'INCH|behave',
#  'behave|3SBJ.DEF.',
#  'some.time|PROG',
#  'PROG|happen[nmlz]',
#  'happen[nmlz]|PROG',
#  'PROG|suddenly',
#  'suddenly|EMP',
#  'EMP|recognize',
#  'recognize|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  '3SG|be.relating.to',
#  'be.relating.to|3OBJ',
#  '3OBJ|NMLZ.A.',
#  'NMLZ.A.|DEM.DIST',
#  'DEM.DIST|be.old',
#  'be.old|NMLZ.A',
#  'PST|EMP',
#  'EMP|see',
#  'see|3SBJ.DEF',
#  '3POSS|NEG.EMPH',
#  'NEG.EMPH|on.account.of',
#  'on.account.of|EMP',
#  'EMP|be.content',
#  'be.content|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  'AFF|DEM',
#  'DEM|3NEG',
#  '3NEG|ITER',
#  'ITER|do.so',
#  'do.so|NEG.',
#  'NEG.|DEM',
#  'no.longer|suck',
#  'suck|eat',
#  'eat|3SBJ.INDF.',
#  '3SBJ.INDF.|some.time',
#  'some.time|when.nmlz',
#  'when.nmlz|PROG',
#  'PROG|happen',
#  'INDF|drag.dim',
#  'drag.dim|NMLZ.P',
#  'NMLZ.P|EMP',
#  'EMP|SUB',
#  'SUB|DIM',
#  'DIM|inside',
#  'PST|INCH',
#  'INCH|so',
#  'so|travel',
#  'travel|3SBJ.DEF',
#  '3SBJ.DEF|grandmother',
#  'grandmother|SUB',
#  'SUB|3POSS',
#  '3POSS|dwell',
#  'dwell|3SBJ.INDF.',
#  '3SBJ.INDF.|DEM',
#  'DEM|PROG',
#  'PROG|do.so',
#  'do.so|3SBJ.DEF',
#  'DEM.DIST|old.woman',
#  'old.woman|PROG',
#  'PROG|go.out',
#  'go.out|whip',
#  'whip|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  'ITER|come',
#  'come|3SBJ.DEF.',
#  '3SBJ.DEF.|mother.sub',
#  'mother.sub|DIM',
#  'DIM|3POSS',
#  'PST|speak.to',
#  'speak.to|3OBJ',
#  '3OBJ|INST',
#  'INST|3SBJ.DEF',
#  '3SBJ.DEF|PROG',
#  'PROG|go.out',
#  'go.out|whip',
#  'whip|TH.PASS',
#  'TH.PASS|3SBJ.PASS.',
#  'PST|think',
#  'think|3SBJ.DEF',
#  '3SBJ.DEF|AFF',
#  'AFF|DEM',
#  'DEM|ITER',
#  'ITER|go[1sbj].',
#  'go.to|go',
#  'go|1SBJ',
#  '1SBJ|[speak.to]3obj',
#  '[speak.to]3obj|INST[1SBJ]',
#  'INST[1SBJ]|AFF.',
#  'AFF.|3SG',
#  '3POSS|child',
#  'child|SUB',
#  'SUB|3POSS',
#  '3POSS|DEM',
#  'DEM|go.to',
#  'go.to|PL',
#  'PL|go.about',
#  'go.about|3SBJ.DEF.',
#  '2NEG|ITER',
#  'ITER|see',
#  'see|EMP',
#  'EMP|1OBJ[2SBJ]',
#  '1OBJ[2SBJ]|AFF',
#  'no.longer|EMP',
#  'EMP|be.fortunate',
#  'be.fortunate|1SBJ.SBJV',
#  '(no.longer|EMP',
#  'EMP|be.fortunate',
#  'be.fortunate|1SBJ.SBJV).',
#  'PST|EMP',
#  'EMP|see',
#  'see|3SBJ.DEF',
#  '3SBJ.DEF|DEM.DIST',
#  'DEM.DIST|old.woman',
#  'at.last|PL',
#  'PL|grow.together',
#  'grow.together|TH.PASS[3SBJ.PASS]',
#  'TH.PASS[3SBJ.PASS]|arm',
#  'arm|3POSS.',
#  'PST|ITER',
#  'ITER|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|UNK',
#  'UNK|be.light',
#  'be.light|NMLZ.A',
#  'NMLZ.A|PST',
#  'PST|EMP',
#  'EMP|see',
#  'see|3SBJ.DEF',
#  'ITER|PL',
#  'PL|toward',
#  'toward|crawl',
#  'crawl|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|EMP',
#  'EMP|PFV',
#  'PFV|get',
#  'get|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  'openwork.plate.|DEM',
#  'DEM|PL',
#  'PL|PROG',
#  'PROG|put.in',
#  'put.in|3SBJ.DEF.',
#  'DEM.DIST|PROG',
#  'PROG|be.warm',
#  'be.warm|NMLZ.INF',
#  'NMLZ.INF|DEM',
#  'DEM|PROG',
#  'PROG|set.upright',
#  'set.upright|3OBJ',
#  '3OBJ|INST',
#  'INST|3SBJ.DEF.',
#  '3NEG|ITER',
#  'ITER|PL',
#  'PL|move',
#  'move|3SBJ.DEF.',
#  '3SBJ.DEF.|INCH',
#  'INCH|get.dark',
#  'get.dark|3SBJ.STV',
#  '3SBJ.STV|DEM',
#  'ITER|PL',
#  'PL|go',
#  'go|TH.CAUS',
#  'TH.CAUS|CAUS',
#  'CAUS|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  'child|then',
#  'then|be.born',
#  'be.born|then',
#  'then|grow.slow',
#  'grow.slow|REFL',
#  'REFL|3SBJ.STV.',
#  'PST|INCH',
#  'INCH|care.for',
#  'care.for|3SBJ.INDF.',
#  '3SBJ.INDF.|ITER',
#  'ITER|be.one',
#  'be.one|EMP',
#  'EMP|UNK',
#  'UNK|next.day',
#  'next.day|NMLZ.A',
#  'PST|go.to',
#  'go.to|gather.wood',
#  'gather.wood|IMPL',
#  'IMPL|DEM.DIST',
#  'DEM.DIST|EMP',
#  'EMP|wear.dress',
#  'wear.dress|NMLZ.A.',
#  'then|CESS',
#  'CESS|INTS',
#  'INTS|3SBJ.IMPL',
#  '3SBJ.IMPL|DEM.DIST',
#  'DEM.DIST|child.',
#  'child.|DEM.DIST',
#  'DEM.DIST|EMP',
#  'EMP|man',
#  'PST|then',
#  'then|EMP',
#  'EMP|care.for',
#  'care.for|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|INCH',
#  'INCH|cry',
#  'cry|3SBJ.DEF.',
#  'be.one|in.vain',
#  'in.vain|treat',
#  'treat|UNK',
#  'UNK|3SBJ.DEF',
#  '3SBJ.DEF|in.vain',
#  'in.vain|sing',
#  'sing|3SBJ.DEF.',
#  '3NEG|CESS',
#  'CESS|cry',
#  'cry|3SBJ.DEF.',
#  '3SBJ.DEF.|what',
#  'what|EMP',
#  'EMP|3SBJ.DEF',
#  '3SBJ.DEF|DEF',
#  'DEF|happen',
#  'happen|NMLZ.P?',
#  'out|go',
#  'go|3SBJ.DEF',
#  '3SBJ.DEF|nettles',
#  'nettles|PST',
#  'PST|go.to',
#  'go.to|get',
#  'get|3SBJ.DEF.',
#  'PST|ITER',
#  'ITER|come.in',
#  'come.in|3SBJ.DEF.',
#  '3SBJ.DEF.|come.in',
#  'come.in|bring',
#  'bring|3SBJ.DEF.',
#  'PST|take.out',
#  'take.out|UNK',
#  'UNK|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|move.into',
#  'move.into|CAUS',
#  'CAUS|3SBJ.DEF',
#  '3SBJ.DEF|nettles',
#  'baby.basket|SUB',
#  'SUB|3.POSS',
#  '3.POSS|SUB',
#  'SUB|LOC.',
#  'LOC.|PST',
#  'PST|ITER',
#  'ITER|put.in',
#  'put.in|3SBJ.DEF.',
#  '3SBJ.DEF.|DEM',
#  'DEM|then',
#  'ITER|INCH',
#  'INCH|cry',
#  'cry|3SBJ.DEF.',
#  '3SBJ.DEF.|3NEG',
#  '3NEG|ITER',
#  'ITER|touch',
#  'touch|UNK',
#  'UNK|3SBJ.DEF.',
#  'DEM.DIST|EMP',
#  'EMP|woman',
#  'woman|PST',
#  'PST|ITER',
#  'ITER|come',
#  'come|3SBJ.DEF.',
#  'no.longer|come.out',
#  'come.out|UNK',
#  'UNK|3SBJ.DEF',
#  '3SBJ.DEF|3POSS',
#  '3POSS|cry',
#  'cry|NMLZ',
#  'NMLZ|3POSS.',
#  'PST|take.out',
#  'take.out|UNK',
#  'UNK|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|EMP',
#  'EMP|see',
#  'see|3SBJ.DEF',
#  '3SBJ.DEF|nettles.',
#  'be.puzzled.over|REFL',
#  'REFL|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|think',
#  'think|3SBJ.DEF.',
#  '3SBJ.DEF.|it.would.be.well',
#  'AFF.|DEM',
#  'DEM|AFF',
#  'AFF|do',
#  'do|3OBJ',
#  '3OBJ|NMLZ.P.',
#  'blow.nose|SUB',
#  'SUB|DIM[1SBJ].',
#  'DIM[1SBJ].|cl.body.part',
#  'cl.body.part|mucus',
#  'mucus|SUB',
#  'SUB|3POSS',
#  'PST|come.out',
#  'come.out|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|take.out',
#  'take.out|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  'PST|INCH',
#  'INCH|treat',
#  'treat|3OBJ',
#  '3OBJ|INST',
#  'INST|3SBJ.DEF',
#  'INCH|wipe',
#  'wipe|by.hand',
#  'by.hand|3OBJ',
#  '3OBJ|INST',
#  'INST|3SBJ.DEF.',
#  '3SBJ.DEF.|INCH',
#  'INCH|CESS',
#  'CESS|cry',
#  'cry|3SBJ.DEF',
#  'CESS|cry',
#  'cry|3SBJ.DEF.',
#  '3SBJ.DEF.|out',
#  'out|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|at.last',
#  'at.last|be.while',
#  'be.while|NMLZ.INF',
#  '3NEG|ITER',
#  'ITER|see',
#  'see|NEG',
#  'NEG|3NEG',
#  '3NEG|ITER',
#  'ITER|see',
#  'see|NEG.',
#  'NEG.|out',
#  'out|go',
#  'go|3SBJ.DEF',
#  'DEM.DIST|EMP',
#  'EMP|man.',
#  'man.|PST',
#  'PST|go.to',
#  'go.to|around',
#  'around|look.for',
#  'look.for|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  '3NEG|INCH',
#  'INCH|EMP',
#  'EMP|see',
#  'see|3SBJ.DEF.',
#  '3SBJ.DEF.|3POSS',
#  '3POSS|tracks',
#  'tracks|3POSS',
#  'PST|EMP',
#  'EMP|see',
#  'see|3SBJ.DEF.',
#  '3SBJ.DEF.|INCH',
#  'INCH|track',
#  'track|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  '3NEG|be.far',
#  'be.far|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|hear',
#  'hear|3SBJ.DEF',
#  '3SBJ.DEF|when',
#  'when|DEF',
#  'DEF|cry',
#  'cry|NMLZ.P.',
#  'upon.arrival|watch',
#  'watch|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  '3SBJ.DEF|3POSS',
#  '3POSS|sit',
#  'sit|NMLZ',
#  'NMLZ|3POSS.',
#  'PST|speak.to',
#  'speak.to|UNK',
#  'UNK|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  '3SBJ.DEF|1POSS',
#  '1POSS|then',
#  'then|EMP',
#  'EMP|see[1sbj]',
#  'EMPH|see',
#  'see|2OBJ[1SBJ].',
#  '2OBJ[1SBJ].|2PROH',
#  '2PROH|ITER',
#  'ITER|think.of',
#  'think.of|TH.1OBJ',
#  'TH.1OBJ|1OBJ',
#  '1OBJ|TH<NEG>SBJV',
#  '3NEG|UNK',
#  'UNK|ITER',
#  'ITER|see',
#  'see|TH.1OBJ',
#  'TH.1OBJ|NEG[2SBJ].',
#  'NEG[2SBJ].|ITER',
#  'ITER|turn',
#  'turn|go',
#  'go|3SBJ.DEF',
#  '3SBJ.DEF|AFF.',
#  'spring|maiden',
#  'maiden|UNK[LOC]',
#  'UNK[LOC]|dwell[3sbj].',
#  'dwell[3sbj].|be.rich',
#  'be.rich|3SBJ.DEF.',
#  '3SBJ.DEF.|always',
#  'PROG|be.one',
#  'be.one|live',
#  'live|3SBJ.DEF.',
#  '3SBJ.DEF.|3NEG',
#  '3NEG|know',
#  'know|TH.IMPL',
#  'TH.IMPL|3SBJ<NMLZ.P>IMPL',
#  'sometime|PROG',
#  'PROG|get.money',
#  'get.money|3SBJ.DEF.',
#  '3SBJ.DEF.|UNK',
#  'PST|INCH',
#  'INCH|love',
#  'love|3OBJ',
#  '3OBJ|UNK',
#  'UNK|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|know',
#  'know|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  'PST|think',
#  'think|3SBJ.DEF',
#  '3SBJ.DEF|AFF',
#  'AFF|sing',
#  'sing|1SBJ',
#  '1SBJ|AFF.',
#  'AFF.|FUT',
#  'FUT|know',
#  'know|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  'DEM.DIST|EMP',
#  'EMP|FUT',
#  'FUT|sing',
#  'sing|NMLZ',
#  'NMLZ|3POSS',
#  '3POSS|breaker.man',
#  'PROG|love',
#  'love|3OBJ',
#  '3OBJ|3SBJ.IMPL.',
#  '3SBJ.IMPL.|PST',
#  'PST|east',
#  'east|that.side',
#  'that.side|DEM',
#  'DEM|dwell[3sbj].',
#  'DEM|PROG',
#  'PROG|EMP',
#  'EMP|PFV',
#  'PFV|go.from',
#  'go.from|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|know',
#  'know|3OBJ',
#  '3OBJ|3SBJ.DEF',
#  '3SG|2SBJ',
#  '2SBJ|3POSS',
#  '3POSS|PROG',
#  'PROG|love',
#  'love|3OBJ.PERS',
#  '3OBJ.PERS|3SBJ<NMLZ>PASS.',
#  '3SBJ<NMLZ>PASS.|now',
#  '1POSS|ITER',
#  'ITER|INCH',
#  'INCH|go',
#  'go|NMLZ.P',
#  'NMLZ.P|PST',
#  'PST|think',
#  'think|3SBJ.DEF',
#  '3SBJ.DEF|there',
#  'there|AFF',
#  'PROG|go.to',
#  'go.to|come[1sbj].',
#  'come[1sbj].|DEM',
#  'DEM|PROG',
#  'PROG|go.to',
#  'go.to|come',
#  'come|3SBJ.DEF.',
#  'come.in|IMP.',
#  'IMP.|come.in',
#  'come.in|3SBJ.DEF.',
#  '3SBJ.DEF.|upon.arrival',
#  'upon.arrival|see',
#  'see|3SBJ.DEF',
#  '3NEG|be.right',
#  'be.right|happen[3sbj]',
#  'happen[3sbj]|be.good',
#  'be.good|3NEG',
#  '3NEG|appear',
#  'appear|NEG.',
#  'PROG|go',
#  'go|1SBJ',
#  '1SBJ|AFF.',
#  'AFF.|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '3SBJ.DEF|six.stick.game',
#  'six.stick.game|AFF',
#  'go.to|CESS',
#  'CESS|NMLZ.P',
#  'NMLZ.P|AFF',
#  'AFF|around',
#  'around|give',
#  'give|2OBJ[1SBJ].',
#  '2OBJ[1SBJ].|PROG',
#  'PROG|go',
#  'go|3SBJ.DEF.',
#  'DEM|now',
#  'now|PROG',
#  'PROG|be.one',
#  'be.one|look.up',
#  'look.up|3SBJ.DEF.',
#  '3SBJ.DEF.|PROG',
#  'PROG|on.account.of',
#  'on.account.of|INCH',
#  'INCH|sprout[3sbj].',
#  'long.ago|EMP',
#  'EMP|3SBJ.DEF',
#  '3SBJ.DEF|3NEG',
#  '3NEG|EMP',
#  'EMP|tide.go.out',
#  'tide.go.out|NMLZ.INF.',
#  'from.one.side|wind.blow',
#  'wind.blow|3SBJ.STV',
#  '3SBJ.STV|southeast',
#  'southeast|wind.blow',
#  'wind.blow|3SBJ.STV.',
#  'INCH|CONT',
#  'CONT|talk',
#  'talk|3SBJ.INDF.',
#  '3SBJ.INDF.|PROG',
#  'PROG|UNK',
#  'UNK|PL',
#  'PL|starve[3sbj]',
#  'be.famine|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|AFF',
#  'AFF|be.large',
#  'be.large|wind.blow',
#  'wind.blow|3SBJ<NMLZ.P>STV',
#  'go.to|EMP',
#  'EMP|buy',
#  'buy|3SBJ.IMPL.',
#  '3SBJ.IMPL.|curlew',
#  'curlew|PST',
#  'PST|go',
#  'go|3SBJ.DEF',
#  '3SBJ.DEF|AFF.',
#  'curlew|PST',
#  'PST|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|behind',
#  'behind|give',
#  'give|3SBJ.INDF',
#  'PFV|PROG',
#  'PROG|PL',
#  'PL|go',
#  'go|cl.hairlike',
#  'cl.hairlike|3OBJ',
#  '3OBJ|3SBJ<NMLZ.P>IMPL.',
#  'DEM|PST',
#  'PST|all',
#  'all|take',
#  'take|3OBJ',
#  '3OBJ|3SBJ.INDF.',
#  '3SBJ.INDF.|trinidad.cove',
#  'PROG|on.arrival',
#  'on.arrival|come',
#  'come|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '3SBJ.DEF|from',
#  'from|south',
#  'south|ADVS',
#  'come.toward[1sbj].|north.wind',
#  'north.wind|around',
#  'around|go.to',
#  'go.to|relating.to',
#  'relating.to|EMP',
#  'EMP|go[1sbj].',
#  '3NEG|EMP',
#  'EMP|tide.go.out',
#  'tide.go.out|NMLZ.INF',
#  'DEM|relating.to',
#  'relating.to|EMP',
#  'EMP|come<nmlz.p>[1sbj].',
#  'come<nmlz.p>[1sbj].|go.to',
#  'go.to|EMP',
#  'EMP|buy',
#  'buy|3OBJ',
#  '3OBJ|1SBJ',
#  'AFF.|FUT',
#  'FUT|give',
#  'give|2OBJ',
#  '2OBJ|dry.kelp.',
#  'dry.kelp.|go.to',
#  'go.to|hand.over',
#  'hand.over|2OBJ[1SBJ]',
#  'be.many|UNK',
#  'UNK|cl.plant',
#  'cl.plant|UNK',
#  'UNK|cl.plant.',
#  'PST|tell',
#  'tell|TH.IMPL',
#  'TH.IMPL|INST.IMPL[3SBJ.PASS]',
#  'INST.IMPL[3SBJ.PASS]|2NEG',
#  '2NEG|take',
#  'take|3OBJ',
#  '3OBJ|NEG',
#  'NEG|AFF.',
#  'PST|say',
#  'say|3SBJ.DEF',
#  '3SBJ.DEF|1POSS',
#  '1POSS|relating.to',
#  'relating.to|take',
#  'take|3OBJ',
#  '3OBJ|1SBJ.',
#  'FUT|see',
#  'see|2SBJ.',
#  '2SBJ.|ITER',
#  'ITER|first',
#  'first|go',
#  'go|3SBJ.DEF',
#  '3SBJ.DEF|AFF',
#  'AFF|halfway',
#  'ITER|go',
#  'go|TH.SBJV',
#  'TH.SBJV|2SBJ<NMLZ.P>SBJV',
#  '2SBJ<NMLZ.P>SBJV|then',
#  'then|ITER',
#  'ITER|look[2sbj.imp]',
#  'look[2sbj.imp]|FUT',
#  'FUT|see',
#  'see|2SBJ.',
#  'PST|EMP',
#  'EMP|see',
#  'see|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|EMP',
#  'EMP|be.glad',
#  'be.glad|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  'PROG|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|INCH',
#  'INCH|UNK',
#  'UNK|be.strong',
#  'be.strong|3POSS.',
#  '3POSS.|toward',
#  'toward|south',
#  'PST|blow.down',
#  'blow.down|3OBJ[3SBJ].',
#  '3OBJ[3SBJ].|3NEG',
#  '3NEG|ITER',
#  'ITER|behind',
#  'behind|get.up',
#  'get.up|3SBJ.DEF.',
#  'PST|blow.down',
#  'blow.down|3OBJ[3SBJ]',
#  '3OBJ[3SBJ]|rock',
#  'rock|SUB',
#  'SUB|LOC.',
#  'LOC.|PST',
#  'PST|through.air',
#  'through.air|move',
#  'move|3SBJ.DEF.',
#  'PST|blow.down',
#  'blow.down|3OBJ[3SBJ].',
#  '3OBJ[3SBJ].|PROG',
#  'PROG|PST',
#  'PST|die[3sbj].',
#  'die[3sbj].|north.wind',
#  'PST|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|PST',
#  'PST|PROG',
#  'PROG|come',
#  'come|3SBJ.DEF',
#  '3SBJ.DEF|south.east',
#  'south.east|that.side.',
#  'PST|EMP',
#  'EMP|tide.go.out',
#  'tide.go.out|NMLZ.INF.',
#  'NMLZ.INF.|clams',
#  'PST|INCH',
#  'INCH|dig.clams',
#  'dig.clams|TH.IMPL',
#  'TH.IMPL|3SBJ.IMPL.',
#  '3NEG|PFV',
#  'PFV|know',
#  'know|TH.1OBJ',
#  'TH.1OBJ|3OBJ[3SBJ].',
#  '3OBJ[3SBJ].|cl.border',
#  'cl.border|EMP',
#  'EMP|around',
#  'then|know',
#  'know|TH.IMPL',
#  'TH.IMPL|3SBJ.IMPL',
#  '3SBJ.IMPL|PROG',
#  'PROG|3POSS',
#  '3POSS|die[3sbj].',
#  'be.long.ago|3SBJ.DEF',
#  '3SBJ.DEF|PFV',
#  'PFV|be.two',
#  'be.two|EMP',
#  'EMP|be.born[3sbj]',
#  'be.born[3sbj]|girl.',
#  'always|PROG',
#  'PROG|be.two',
#  'be.two|live',
#  'live|3SBJ.DEF.',
#  '3SBJ.DEF.|PROG',
#  'PROG|be.one',
#  'be.one|cl.time',
#  'cl.time|3SBJ.DEF',
#  'PROG|PROG',
#  'PROG|do',
#  'do|3OBJ',
#  '3OBJ|3SBJ.DEF.',
#  '3SBJ.DEF.|PROG',
#  'PROG|3NEG',
#  '3NEG|be.good',
#  'be.good|do',
#  'do|3SBJ.DEF',
#  'stay|EMP',
#  'EMP|CONT',
#  'CONT|dwell[3sbj]',
#  'dwell[3sbj]|PROG',
#  'PROG|cook',
#  'cook|3SBJ.DEF.',
#  '3SBJ.DEF.|3NEG',
#  '3NEG|EMP',
#  'EMP|see',
#  'see|NEG',
#  'NEG|man.',
#  'PROG|PROG',
#  'PROG|very',
#  'very|be.much',
#  'be.much|prepare',
#  'prepare|3SBJ<TH.IMPL>IMPL.',
#  ...]

# %%
# Out:
# 11

# %%
`
# Out:
# 'Sample Text'

# %%
tmp = reichard[list(reichard.keys())[2]]

# %%
_isna = lambda x: x.isna()

# %%
tmp[~tmp.apply(_isna,0).all(1)]
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# 0            x   Dakwhłír         ił         ho  tatkónawokš    carórił
# 1            x      Chase     NMLZ.A       INDF          UNK       girl
# 2          NaN        NaN        NaN        NaN          NaN        NaN
# 3            x         wu        dít         wu          luw        akw
# 4            x   DEM.PROX     be.two        PFV         come       NMLZ
# ..         ...        ...        ...        ...          ...        ...
# 371        NaN        NaN        NaN        NaN          NaN        NaN
# 372        NaN        NaN        NaN        NaN          NaN        NaN
# 373        NaN        NaN        NaN        NaN          NaN        NaN
# 374        NaN        NaN        NaN        NaN          NaN        NaN
# 375        NaN        NaN        NaN        NaN          NaN        NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0          NaN        NaN        NaN        NaN         NaN         NaN
# 1          NaN        NaN        NaN        NaN         NaN         NaN
# 2          NaN        NaN        NaN        NaN         NaN         NaN
# 3          ahl        wik      bohd.        NaN         NaN         NaN
# 4        3POSS       from     north.        NaN         NaN         NaN
# ..         ...        ...        ...        ...         ...         ...
# 371        NaN        NaN        NaN        NaN         NaN         NaN
# 372        NaN        NaN        NaN        NaN         NaN         NaN
# 373        NaN        NaN        NaN        NaN         NaN         NaN
# 374        NaN        NaN        NaN        NaN         NaN         NaN
# 375        NaN        NaN        NaN        NaN         NaN         NaN
#
#      Unnamed: 12        Wiyot            English
# 0            NaN     Dakwhłír              Chase
# 1            NaN           ił             NMLZ.A
# 2            NaN           ho               INDF
# 3            NaN  tatkónawokš                UNK
# 4            NaN      carórił               girl
# ..           ...          ...                ...
# 371          NaN           to               PROG
# 372          NaN           hu              3POSS
# 373          NaN           tó               PROG
# 374          NaN          kow              do.to
# 375          NaN       a<h>n.  3SBJ<NMLZ.P>PASS.
#
# [376 rows x 15 columns]

# %%
for i in range(len(reichard)):
    print('----')
    print(story)
    story = list(reichard.keys())[i]
    tmp = getWordPairsFromText(reichard[story])
    print(tmp)
# Out:
# ----
# 49. Fox Text 2
# ['long.ago|3SBJ.DEF', '3SBJ.DEF|girl', 'girl|be.one', 'be.one|EMP', 'EMP|CESS', 'CESS|grow', 'grow|REFL', 'REFL|3SBJ.DEF.', 'DEM|INCH', 'INCH|do.so', 'do.so|3SBJ.DEF', '3SBJ.DEF|grass', 'PROG|go.about', 'go.about|NMLZ', 'NMLZ|SUB', 'SUB|3POSS', '3POSS|stick', 'stick|around', 'around|carry', 'carry|3OBJ', '3OBJ|3SBJ.DEF.', 'stick|around', 'around|hit', 'hit|EMP', 'EMP|cl.hairlike', 'cl.hairlike|move.aside', 'move.aside|3OBJ', '3OBJ|3SBJ.DEF', '3POSS|scare', 'scare|NMLZ.INF', 'NMLZ.INF|SUB', 'SUB|3POSS', '3POSS|CESS', 'CESS|PROB', 'PROB|see', 'see|1SBJ', 'around|drag', 'drag|NMLZ.P.', 'NMLZ.P.|DEM', 'DEM|around', 'around|do.so', 'do.so|3SBJ.DEF.', 'some.time|when.nmlz', 'when.nmlz|PROG', 'PROG|happen', 'PST|go.to', 'go.to|gather.heracleum.lanatum', 'gather.heracleum.lanatum|3SBJ.INDF.', 'PST|PROG', 'PROG|on.arrival', 'on.arrival|land', 'land|3SBJ.STV.', 'INCH|gather.heracleum.lanatum', 'gather.heracleum.lanatum|3SBJ.INDF.', 'soon|INCH', 'INCH|carry.load.on.back.dim', 'carry.load.on.back.dim|affect', 'affect|TH.IMPL[3SBJ].', 'PST|call.in.woods', 'call.in.woods|TH.IMPL[3SBJ]', 'TH.IMPL[3SBJ]|DEM.DIST', 'DEM.DIST|girl.', 'PST|tell', 'tell|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ.PASS]', 'INST.IMPL[3SBJ.PASS]|ITER', 'ITER|INCH', 'INCH|travel[1sbj.pl]', 'travel[1sbj.pl]|AFF.', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|all.right.', 'all.right.|ITER', 'ITER|INCH', 'INCH|EMP', 'EMP|go[3sbj]', 'go[3sbj]|AFF.', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|INCH', 'INCH|carry.load[1sbj]', 'carry.load[1sbj]|AFF.', 'in.vain|pull.with.hands', 'pull.with.hands|3OBJ', '3OBJ|3SBJ.DEF', '3POSS|DEM.PROX', 'DEM.PROX|carry.load.on.back.dim', 'carry.load.on.back.dim|NMLZ.INF', 'NMLZ.INF|SUB', 'SUB|3POSS.', 'then|ITER', 'ITER|be.up', 'be.up|stand', 'stand|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|look.at', 'look.at|3OBJ', '3OBJ|3SBJ.DEF.', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', '3SBJ.DEF|INDF', 'INDF|drag', 'drag|NMLZ.P', '3POSS|PROG', 'PROG|lie', 'lie|3SBJ.STV.', '3SBJ.STV.|surely', 'around|on.the.move', 'on.the.move|grasp', 'grasp|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|DEM', '3NEG|be.up', 'be.up|carry.load.on.back', 'carry.load.on.back|3SBJ.DEF.', 'PST|tell', 'tell|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ.PASS]', 'INST.IMPL[3SBJ.PASS]|AFF', 'INCH|accompany', 'accompany|2SBJ.IMP.', '2SBJ.IMP.|already', 'already|see', 'see|2OBJ[1SBJ]', 'DEM|2POSS', '2POSS|PROG', 'PROG|do.so', 'do.so|2SBJ.SBJV', 'when.2sbj|PROG', 'PROG|go.about', 'go.about|2SBJ.SBJV', 'stick|2POSS', '2POSS|around', 'around|carry', 'carry|3OBJ', '3OBJ|2SBJ.SBJV', '2POSS|around', 'around|hit', 'hit|EMP', 'EMP|cl.hairlike', 'cl.hairlike|move.aside', 'move.aside|3OBJ', '3OBJ|2SBJ.SBJV.', '2SBJ.SBJV.|now', 'DEM|go.to', 'go.to|come.to.get', 'come.to.get|2OBJ[1SBJ].', '2OBJ[1SBJ].|PST', 'PST|over', 'over|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|water', 'go.to|on.arrival', 'on.arrival|PROG', 'PROG|on.arrival', 'on.arrival|go.through.enclosure', 'go.through.enclosure|3SBJ.DEF.', 'DEM.PROX|also', 'also|around', 'around|feel.like', 'feel.like|3SBJ.DEF', 'PST|ITER', 'ITER|feel.like', 'feel.like|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|on.arrival', 'on.arrival|see', 'see|3OBJ', '3OBJ|3SBJ.DEF', '3POSS|inside.', 'inside.|PST', 'PST|on.arrival', 'on.arrival|go.through.enclosure', 'go.through.enclosure|3SBJ.DEF.', 'upon.arrival|see', 'see|3OBJ', '3OBJ|3SBJ.DEF', 'go.down.into|at.end.of', 'at.end.of|do.with.face', 'do.with.face|lie', 'lie|3SBJ.STV.', '3SBJ.STV.|have.sense', 'have.sense|NMLZ.A', 'NMLZ.A|3PL', 'only|PROG', 'PROG|PL', 'PL|be.at.home[3sbj].', 'soon|PST', 'PST|hear.noise', 'hear.noise|3SBJ.DEF', '3SBJ.DEF|3POSS', '3POSS|creak', 'creak|NMLZ.INF.', 'DEM.DIST|woods', 'woods|PFV', 'PFV|go.about', 'go.about|3SBJ.DEF', '3SBJ.DEF|ITER', 'ITER|come', 'come|3SBJ.DEF.', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', '3SBJ.DEF|ITER', 'ITER|go.through.enclosure', 'go.through.enclosure|NMLZ.INF', 'NMLZ.INF|SUB', 'SUB|3POSS.', 'DEM|PST', 'PST|ITER', 'ITER|each', 'each|lie', 'lie|3SBJ.STV.', '3SBJ.STV.|soon', 'PST|ITER', 'ITER|hear.noise', 'hear.noise|3SBJ.DEF', '3 ...
# ----
# Sample Text
# ['child|then', 'then|be.born', 'be.born|then', 'then|grow.slow', 'grow.slow|REFL', 'REFL|3SBJ.STV.', 'PST|INCH', 'INCH|care.for', 'care.for|3SBJ.INDF.', '3SBJ.INDF.|ITER', 'ITER|be.one', 'be.one|EMP', 'EMP|UNK', 'UNK|next.day', 'next.day|NMLZ.A', 'PST|go.to', 'go.to|gather.wood', 'gather.wood|IMPL', 'IMPL|DEM.DIST', 'DEM.DIST|EMP', 'EMP|wear.dress', 'wear.dress|NMLZ.A.', 'then|CESS', 'CESS|INTS', 'INTS|3SBJ.IMPL', '3SBJ.IMPL|DEM.DIST', 'DEM.DIST|child.', 'child.|DEM.DIST', 'DEM.DIST|EMP', 'EMP|man', 'PST|then', 'then|EMP', 'EMP|care.for', 'care.for|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|INCH', 'INCH|cry', 'cry|3SBJ.DEF.', 'be.one|in.vain', 'in.vain|treat', 'treat|UNK', 'UNK|3SBJ.DEF', '3SBJ.DEF|in.vain', 'in.vain|sing', 'sing|3SBJ.DEF.', '3NEG|CESS', 'CESS|cry', 'cry|3SBJ.DEF.', '3SBJ.DEF.|what', 'what|EMP', 'EMP|3SBJ.DEF', '3SBJ.DEF|DEF', 'DEF|happen', 'happen|NMLZ.P?', 'out|go', 'go|3SBJ.DEF', '3SBJ.DEF|nettles', 'nettles|PST', 'PST|go.to', 'go.to|get', 'get|3SBJ.DEF.', 'PST|ITER', 'ITER|come.in', 'come.in|3SBJ.DEF.', '3SBJ.DEF.|come.in', 'come.in|bring', 'bring|3SBJ.DEF.', 'PST|take.out', 'take.out|UNK', 'UNK|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|move.into', 'move.into|CAUS', 'CAUS|3SBJ.DEF', '3SBJ.DEF|nettles', 'baby.basket|SUB', 'SUB|3.POSS', '3.POSS|SUB', 'SUB|LOC.', 'LOC.|PST', 'PST|ITER', 'ITER|put.in', 'put.in|3SBJ.DEF.', '3SBJ.DEF.|DEM', 'DEM|then', 'ITER|INCH', 'INCH|cry', 'cry|3SBJ.DEF.', '3SBJ.DEF.|3NEG', '3NEG|ITER', 'ITER|touch', 'touch|UNK', 'UNK|3SBJ.DEF.', 'DEM.DIST|EMP', 'EMP|woman', 'woman|PST', 'PST|ITER', 'ITER|come', 'come|3SBJ.DEF.', 'no.longer|come.out', 'come.out|UNK', 'UNK|3SBJ.DEF', '3SBJ.DEF|3POSS', '3POSS|cry', 'cry|NMLZ', 'NMLZ|3POSS.', 'PST|take.out', 'take.out|UNK', 'UNK|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', '3SBJ.DEF|nettles.', 'be.puzzled.over|REFL', 'REFL|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|think', 'think|3SBJ.DEF.', '3SBJ.DEF.|it.would.be.well', 'AFF.|DEM', 'DEM|AFF', 'AFF|do', 'do|3OBJ', '3OBJ|NMLZ.P.', 'blow.nose|SUB', 'SUB|DIM[1SBJ].', 'DIM[1SBJ].|cl.body.part', 'cl.body.part|mucus', 'mucus|SUB', 'SUB|3POSS', 'PST|come.out', 'come.out|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|take.out', 'take.out|3OBJ', '3OBJ|3SBJ.DEF.', 'PST|INCH', 'INCH|treat', 'treat|3OBJ', '3OBJ|INST', 'INST|3SBJ.DEF', 'INCH|wipe', 'wipe|by.hand', 'by.hand|3OBJ', '3OBJ|INST', 'INST|3SBJ.DEF.', '3SBJ.DEF.|INCH', 'INCH|CESS', 'CESS|cry', 'cry|3SBJ.DEF', 'CESS|cry', 'cry|3SBJ.DEF.', '3SBJ.DEF.|out', 'out|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|at.last', 'at.last|be.while', 'be.while|NMLZ.INF', '3NEG|ITER', 'ITER|see', 'see|NEG', 'NEG|3NEG', '3NEG|ITER', 'ITER|see', 'see|NEG.', 'NEG.|out', 'out|go', 'go|3SBJ.DEF', 'DEM.DIST|EMP', 'EMP|man.', 'man.|PST', 'PST|go.to', 'go.to|around', 'around|look.for', 'look.for|3OBJ', '3OBJ|3SBJ.DEF.', '3NEG|INCH', 'INCH|EMP', 'EMP|see', 'see|3SBJ.DEF.', '3SBJ.DEF.|3POSS', '3POSS|tracks', 'tracks|3POSS', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF.', '3SBJ.DEF.|INCH', 'INCH|track', 'track|3OBJ', '3OBJ|3SBJ.DEF.', '3NEG|be.far', 'be.far|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|hear', 'hear|3SBJ.DEF', '3SBJ.DEF|when', 'when|DEF', 'DEF|cry', 'cry|NMLZ.P.', 'upon.arrival|watch', 'watch|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|3POSS', '3POSS|sit', 'sit|NMLZ', 'NMLZ|3POSS.', 'PST|speak.to', 'speak.to|UNK', 'UNK|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|1POSS', '1POSS|then', 'then|EMP', 'EMP|see[1sbj]', 'EMPH|see', 'see|2OBJ[1SBJ].', '2OBJ[1SBJ].|2PROH', '2PROH|ITER', 'ITER|think.of', 'think.of|TH.1OBJ', 'TH.1OBJ|1OBJ', '1OBJ|TH<NEG>SBJV', '3NEG|UNK', 'UNK|ITER', 'ITER|see', 'see|TH.1OBJ', 'TH.1OBJ|NEG[2SBJ].', 'NEG[2SBJ].|ITER', 'ITER|turn', 'turn|go', 'go|3SBJ.DEF', '3SBJ.DEF|AFF.']
# ----
# 1. Nettle Medicine
# []
# ----
# 2. Wolf's Home
# ['spring|maiden', 'maiden|UNK[LOC]', 'UNK[LOC]|dwell[3sbj].', 'dwell[3sbj].|be.rich', 'be.rich|3SBJ.DEF.', '3SBJ.DEF.|always', 'PROG|be.one', 'be.one|live', 'live|3SBJ.DEF.', '3SBJ.DEF.|3NEG', '3NEG|know', 'know|TH.IMPL', 'TH.IMPL|3SBJ<NMLZ.P>IMPL', 'sometime|PROG', 'PROG|get.money', 'get.money|3SBJ.DEF.', '3SBJ.DEF.|UNK', 'PST|INCH', 'INCH|love', 'love|3OBJ', '3OBJ|UNK', 'UNK|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|know', 'know|3OBJ', '3OBJ|3SBJ.DEF.', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|AFF', 'AFF|sing', 'sing|1SBJ', '1SBJ|AFF.', 'AFF.|FUT', 'FUT|know', 'know|3OBJ', '3OBJ|3SBJ.DEF', 'DEM.DIST|EMP', 'EMP|FUT', 'FUT|sing', 'sing|NMLZ', 'NMLZ|3POSS', '3POSS|breaker.man', 'PROG|love', 'love|3OBJ', '3OBJ|3SBJ.IMPL.', '3SBJ.IMPL.|PST', 'PST|east', 'east|that.side', 'that.side|DEM', 'DEM|dwell[3sbj].', 'DEM|PROG', 'PROG|EMP', 'EMP|PFV', 'PFV|go.from', 'go.from|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|know', 'know|3OBJ', '3OBJ|3SBJ.DEF', '3SG|2SBJ', '2SBJ|3POSS', '3POSS|PROG', 'PROG|love', 'love|3OBJ.PERS', '3OBJ.PERS|3SBJ<NMLZ>PASS.', '3SBJ<NMLZ>PASS.|now', '1POSS|ITER', 'ITER|INCH', 'INCH|go', 'go|NMLZ.P', 'NMLZ.P|PST', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|there', 'there|AFF', 'PROG|go.to', 'go.to|come[1sbj].', 'come[1sbj].|DEM', 'DEM|PROG', 'PROG|go.to', 'go.to|come', 'come|3SBJ.DEF.', 'come.in|IMP.', 'IMP.|come.in', 'come.in|3SBJ.DEF.', '3SBJ.DEF.|upon.arrival', 'upon.arrival|see', 'see|3SBJ.DEF', '3NEG|be.right', 'be.right|happen[3sbj]', 'happen[3sbj]|be.good', 'be.good|3NEG', '3NEG|appear', 'appear|NEG.', 'PROG|go', 'go|1SBJ', '1SBJ|AFF.', 'AFF.|PST', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|six.stick.game', 'six.stick.game|AFF', 'go.to|CESS', 'CESS|NMLZ.P', 'NMLZ.P|AFF', 'AFF|around', 'around|give', 'give|2OBJ[1SBJ].', '2OBJ[1SBJ].|PROG', 'PROG|go', 'go|3SBJ.DEF.', 'DEM|now', 'now|PROG', 'PROG|be.one', 'be.one|look.up', 'look.up|3SBJ.DEF.', '3SBJ.DEF.|PROG', 'PROG|on.account.of', 'on.account.of|INCH', 'INCH|sprout[3sbj].']
# ----
# 3. Spring Maiden
# ['long.ago|EMP', 'EMP|3SBJ.DEF', '3SBJ.DEF|3NEG', '3NEG|EMP', 'EMP|tide.go.out', 'tide.go.out|NMLZ.INF.', 'from.one.side|wind.blow', 'wind.blow|3SBJ.STV', '3SBJ.STV|southeast', 'southeast|wind.blow', 'wind.blow|3SBJ.STV.', 'INCH|CONT', 'CONT|talk', 'talk|3SBJ.INDF.', '3SBJ.INDF.|PROG', 'PROG|UNK', 'UNK|PL', 'PL|starve[3sbj]', 'be.famine|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|AFF', 'AFF|be.large', 'be.large|wind.blow', 'wind.blow|3SBJ<NMLZ.P>STV', 'go.to|EMP', 'EMP|buy', 'buy|3SBJ.IMPL.', '3SBJ.IMPL.|curlew', 'curlew|PST', 'PST|go', 'go|3SBJ.DEF', '3SBJ.DEF|AFF.', 'curlew|PST', 'PST|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|behind', 'behind|give', 'give|3SBJ.INDF', 'PFV|PROG', 'PROG|PL', 'PL|go', 'go|cl.hairlike', 'cl.hairlike|3OBJ', '3OBJ|3SBJ<NMLZ.P>IMPL.', 'DEM|PST', 'PST|all', 'all|take', 'take|3OBJ', '3OBJ|3SBJ.INDF.', '3SBJ.INDF.|trinidad.cove', 'PROG|on.arrival', 'on.arrival|come', 'come|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|from', 'from|south', 'south|ADVS', 'come.toward[1sbj].|north.wind', 'north.wind|around', 'around|go.to', 'go.to|relating.to', 'relating.to|EMP', 'EMP|go[1sbj].', '3NEG|EMP', 'EMP|tide.go.out', 'tide.go.out|NMLZ.INF', 'DEM|relating.to', 'relating.to|EMP', 'EMP|come<nmlz.p>[1sbj].', 'come<nmlz.p>[1sbj].|go.to', 'go.to|EMP', 'EMP|buy', 'buy|3OBJ', '3OBJ|1SBJ', 'AFF.|FUT', 'FUT|give', 'give|2OBJ', '2OBJ|dry.kelp.', 'dry.kelp.|go.to', 'go.to|hand.over', 'hand.over|2OBJ[1SBJ]', 'be.many|UNK', 'UNK|cl.plant', 'cl.plant|UNK', 'UNK|cl.plant.', 'PST|tell', 'tell|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ.PASS]', 'INST.IMPL[3SBJ.PASS]|2NEG', '2NEG|take', 'take|3OBJ', '3OBJ|NEG', 'NEG|AFF.', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|1POSS', '1POSS|relating.to', 'relating.to|take', 'take|3OBJ', '3OBJ|1SBJ.', 'FUT|see', 'see|2SBJ.', '2SBJ.|ITER', 'ITER|first', 'first|go', 'go|3SBJ.DEF', '3SBJ.DEF|AFF', 'AFF|halfway', 'ITER|go', 'go|TH.SBJV', 'TH.SBJV|2SBJ<NMLZ.P>SBJV', '2SBJ<NMLZ.P>SBJV|then', 'then|ITER', 'ITER|look[2sbj.imp]', 'look[2sbj.imp]|FUT', 'FUT|see', 'see|2SBJ.', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|EMP', 'EMP|be.glad', 'be.glad|3OBJ', '3OBJ|3SBJ.DEF.', 'PROG|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|INCH', 'INCH|UNK', 'UNK|be.strong', 'be.strong|3POSS.', '3POSS.|toward', 'toward|south', 'PST|blow.down', 'blow.down|3OBJ[3SBJ].', '3OBJ[3SBJ].|3NEG', '3NEG|ITER', 'ITER|behind', 'behind|get.up', 'get.up|3SBJ.DEF.', 'PST|blow.down', 'blow.down|3OBJ[3SBJ]', '3OBJ[3SBJ]|rock', 'rock|SUB', 'SUB|LOC.', 'LOC.|PST', 'PST|through.air', 'through.air|move', 'move|3SBJ.DEF.', 'PST|blow.down', 'blow.down|3OBJ[3SBJ].', '3OBJ[3SBJ].|PROG', 'PROG|PST', 'PST|die[3sbj].', 'die[3sbj].|north.wind', 'PST|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|PROG', 'PROG|come', 'come|3SBJ.DEF', '3SBJ.DEF|south.east', 'south.east|that.side.', 'PST|EMP', 'EMP|tide.go.out', 'tide.go.out|NMLZ.INF.', 'NMLZ.INF.|clams', 'PST|INCH', 'INCH|dig.clams', 'dig.clams|TH.IMPL', 'TH.IMPL|3SBJ.IMPL.', '3NEG|PFV', 'PFV|know', 'know|TH.1OBJ', 'TH.1OBJ|3OBJ[3SBJ].', '3OBJ[3SBJ].|cl.border', 'cl.border|EMP', 'EMP|around', 'then|know', 'know|TH.IMPL', 'TH.IMPL|3SBJ.IMPL', '3SBJ.IMPL|PROG', 'PROG|3POSS', '3POSS|die[3sbj].']
# ----
# 4. Curlew
# ['be.long.ago|3SBJ.DEF', '3SBJ.DEF|PFV', 'PFV|be.two', 'be.two|EMP', 'EMP|be.born[3sbj]', 'be.born[3sbj]|girl.', 'always|PROG', 'PROG|be.two', 'be.two|live', 'live|3SBJ.DEF.', '3SBJ.DEF.|PROG', 'PROG|be.one', 'be.one|cl.time', 'cl.time|3SBJ.DEF', 'PROG|PROG', 'PROG|do', 'do|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|PROG', 'PROG|3NEG', '3NEG|be.good', 'be.good|do', 'do|3SBJ.DEF', 'stay|EMP', 'EMP|CONT', 'CONT|dwell[3sbj]', 'dwell[3sbj]|PROG', 'PROG|cook', 'cook|3SBJ.DEF.', '3SBJ.DEF.|3NEG', '3NEG|EMP', 'EMP|see', 'see|NEG', 'NEG|man.', 'PROG|PROG', 'PROG|very', 'very|be.much', 'be.much|prepare', 'prepare|3SBJ<TH.IMPL>IMPL.', '3SBJ<TH.IMPL>IMPL.|DEM.DIST', 'DEM.DIST|girl', 'think.about|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|always', 'always|3PL', '3POSS|PROG', 'PROG|be.two', 'be.two|live', 'live|NMLZ', 'NMLZ|3POSS.', '3POSS.|wood', 'wood|bring', 'bring|3SBJ.INDF.', 'always|only', 'only|PROG', 'PROG|do', 'do|3SBJ.DEF', '3SBJ.DEF|wood', 'INCH|go.in', 'go.in|by.hand', 'by.hand|NMLZ.P.', 'NMLZ.P.|always', 'always|PROG', 'PROG|do.so', 'do.so|3SBJ.DEF.', 'INCH|think.about', 'think.about|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|darken', 'darken|3SBJ.STV[NMLZ]', '1NEG|NEG.EMPH', 'NEG.EMPH|go.to.sleep', 'go.to.sleep|NEG', 'NEG|AFF.', 'AFF.|be.in.love', 'be.in.love|1SBJ', 'know|3OBJ', '3OBJ|1SBJ.SBJV.', '1SBJ.SBJV.|lie.down', 'lie.down|3SBJ.STV.', '3SBJ.STV.|be.midnight', 'be.midnight|same.way', 'same.way|go[3sbj]', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', '3SBJ.DEF|out', 'out|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|UNK', 'UNK|be.soon', 'be.soon|NMLZ.INF', 'ITER|come.in', 'come.in|3SBJ.DEF.', '3SBJ.DEF.|wood', 'wood|go.in', 'go.in|carry', 'carry|3SBJ.INDF.', 'put.down.into|burn', 'burn|3SBJ.IMPL.', '3SBJ.IMPL.|INCH', 'INCH|cook<nmlz.p>.', 'cook<nmlz.p>.|hear', 'hear|3SBJ.DEF', 'partition|SUB', 'SUB|LOC.', 'LOC.|PST', 'PST|move', 'move|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', 'DEM.DIST|EMP', 'EMP|come.in', 'come.in|NMLZ.INF', 'NMLZ.INF|3POSS', '3POSS|be.filthy[3sbj]', '[have]nasal.mucus|SUB', 'SUB|1SBJ.SBJV[NMLZ].', '1SBJ.SBJV[NMLZ].|north.wind', 'north.wind|UNK', 'PST|go.in', 'go.in|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|INCH', 'INCH|eat', 'eat|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|CESS', 'CESS|eat', 'eat|3SBJ.DEF.', 'ITER|out', 'out|go[3sbj].', 'go[3sbj].|wood', 'wood|hear.person', 'hear.person|3OBJ', '3OBJ|3SBJ.DEF.', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|there', 'there|AFF', 'AFF|stay[3sbj].', 'PROG|lie.down', 'lie.down|3SBJ.STV.', '3SBJ.STV.|PST', 'PST|be.light[nmlz]', 'PST|EMP', 'EMP|feast', 'feast|3SBJ.INDF.', 'CESS|eat', 'eat|3SBJ.INDF.', '3SBJ.INDF.|PST', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|1NEG', '1NEG|EMP', 'EMP|gather<neg>wood', 'AFF|wood', 'wood|be.enough', 'be.enough|EMP', 'EMP|3SBJ.STV.', '3SBJ.STV.|PST', 'PST|say', 'say|3SBJ.DEF', 'be.one|INCH', 'INCH|have.sense', 'have.sense|TH.IMPL[1SBJ]', 'TH.IMPL[1SBJ]|AFF.', 'be.good|CONT', 'CONT|EMP', 'EMP|happen[3sbj].', 'happen[3sbj].|wood', 'wood|be.nice', 'be.nice|PROG', 'PROG|PL', 'PL|stand.up', 'stand.up|CAUS[3SBJ].', 'very|be.many', 'be.many|3SBJ.STV', '3SBJ.STV|wood.chip.', 'wood.chip.|out', 'out|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|wood', 'be.nice|INCH', 'INCH|arrange', 'arrange|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|INCH', 'INCH|move', 'move|CAUS', 'CAUS|3SBJ.INDF.', '3NEG|be.much', 'be.much|go.to', 'go.to|move', 'move|CAUS', 'CAUS|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', 'man|3POSS', '3POSS|sit', 'sit|NMLZ.INF', 'NMLZ.INF|3POSS.', '3POSS.|PST', 'PST|recognize', 'recognize|3OBJ', '3OBJ|3SBJ.DEF.', 'DEM|relating.to', 'relating.to|last.night', 'last.night|DEM', 'DEM|PFV', 'PFV|come.in', 'come.in|3SBJ.DEF.', 'out|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|NEG.EMPH', 'NEG.EMPH|3NEG', '3NEG|talk.to', 'talk.to|3OBJ', '3OBJ|3SBJ.DEF.', 'PROG|relating.to', 'relating.to|3NEG', '3NEG|say', 'say|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|3NEG', '3NEG|be.far', 'be.far|go', 'go|3SBJ.DEF.', 'DEM|PROG', 'PROG|say', 'say|3SBJ.DEF', '3SBJ.DEF|surely', 'surely|be.good', 'be.good|FUT', 'F ...
# ----
# 5. North Wind
# ['killer.whale|DEM', 'DEM|dwell[3sbj]', 'wood|lie.there', 'lie.there|3SBJ.PASS[NMLZ.LOC].', 'at.last|be.long.time', 'be.long.time|EMP', 'EMP|live.there[3sbj].', 'live.there[3sbj].|DEM', 'EMPH|leave.pass', 'leave.pass|be.content', 'be.content|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|say', 'say|TH.IMPL', 'TH.IMPL|INST.IMPL', 'whatever|think', 'think|TH.SBJV', 'TH.SBJV|2SBJ.SBJV?', '2SBJ.SBJV?|PST', 'PST|say', 'say|3SBJ.DEF', 'no.longer|stay[1sbj]', 'stay[1sbj]|AFF.', 'AFF.|3NEG', '3NEG|be.content[1sbj].', 'be.content[1sbj].|PST', 'PST|go', 'go|3SBJ.DEF.', '3NEG|be.far', 'be.far|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|UNK', 'PST|PROG', 'PROG|on.arrival', 'on.arrival|come', 'come|3SBJ.DEF.', '3SBJ.DEF.|be.one', 'be.one|cl.year', 'cl.year|3POSS', '3POSS|stay[3sbj].', 'suddenly|ITER', 'ITER|say', 'say|3SBJ.DEF', '3SBJ.DEF|1NEG', '1NEG|be.content', 'be.content|NEG.', 'NEG.|whatever', 'think|TH.SBJV', 'TH.SBJV|2SBJ.SBJV?', '2SBJ.SBJV?|coyote', 'coyote|PST', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|yesterday', 'day.before|no.longer', 'no.longer|EMP', 'EMP|be.content', 'be.content|NEG[1SBJ].', 'be.nice|EMP', 'EMP|INCH', 'INCH|up', 'up|affect', 'affect|REFL[3SBJ]', 'REFL[3SBJ]|INCH', 'INCH|paint.body', 'paint.body|REFL[3SBJ].', 'PROG|CESS', 'CESS|paint.body', 'paint.body|REFL', 'REFL|3SBJ.DEF.', '3SBJ.DEF.|all', 'all|go[3sbj].', 'go[3sbj].|coyote', 'PST|say', 'say|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ.PASS]', 'INST.IMPL[3SBJ.PASS]|DEM', 'DEM|AFF', 'AFF|stay', 'stay|HORT.2SBJ', 'be.good|3NEG', '3NEG|be.so[3sbj]', 'be.so[3sbj]|PROG', 'PROG|FUT', 'FUT|give.food', 'give.food|2OBJ', 'PROG|go.to', 'go.to|go.over', 'go.over|3SBJ.DEF', '3SBJ.DEF|ocean', 'ocean|drink', 'drink|NMLZ.P', 'NMLZ.P|tomorrow.', 'DEM.PROX|EMP', 'EMP|AFF', 'AFF|go[1sbj]', 'go[1sbj]|land', 'land|SUB', 'SUB|LOC', 'LOC|AFF', '1NEG|so', 'so|go[1sbj]', 'go[1sbj]|toward', 'toward|ocean.', 'ocean.|PST', 'PST|then', 'then|all', 'all|go.over', 'go.over|3SBJ.INDF', 'ocean|INDF', 'INDF|do', 'do|NMLZ.INF', 'NMLZ.INF|(INDF', '(INDF|do', 'do|NMLZ.INF)', 'PST|PROG', 'PROG|on.arrival', 'on.arrival|all', 'all|come', 'come|3SBJ.INDF.', 'upon.arrival|go.down.into', 'go.down.into|3SBJ.INDF', '3SBJ.INDF|PST', 'PST|go.ashore', 'go.ashore|LOC', 'LOC|NMLZ.INF.', 'PST|dive.before.breakers.come.in', 'dive.before.breakers.come.in|3SBJ.INDF', '(PST|dive.before.breakers.come.in', 'dive.before.breakers.come.in|3SBJ.INDF).', '3SBJ.INDF).|PST', 'PST|all', 'all|go.down.in', 'go.down.in|3SBJ.INDF.', 'coyote|PST', 'PST|go.in[3sbj]', 'go.in[3sbj]|EMPH', 'EMPH|put', 'put|head', 'head|CAUS', 'CAUS|3SBJ.DEF', '3SBJ.DEF|water.', 'PST|go.up', 'go.up|3SBJ.DEF', '3SBJ.DEF|river.bank', 'river.bank|way.up', 'way.up|lie', 'lie|3SBJ.STV.', '3SBJ.STV.|DEM', 'PROG|be.large', 'be.large|sit', 'sit|3SBJ.DEF.', '3SBJ.DEF.|3NEG', '3NEG|ITER', 'ITER|go', 'go|3SBJ.DEF', '3SBJ.DEF|toward', 'toward|ocean.', 'PST|look.down', 'look.down|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', 'all|come.to.surface', 'come.to.surface|3SBJ.STV', '3SBJ.STV|PST', 'PST|all', 'all|go.off[3sbj].', 'go.off[3sbj].|coyote', 'PST|INCH', 'INCH|cry', 'cry|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|ITER', 'ITER|go.over', 'go.over|3SBJ.DEF.', 'PROG|ITER', 'ITER|come', 'come|3SBJ.DEF.', '3SBJ.DEF.|be.in', 'be.in|NMLZ.P', 'PST|on.arrival', 'on.arrival|lie.down', 'lie.down|3SBJ.STV', '3SBJ.STV|1NEG', '1NEG|ITER', 'ITER|eat', 'eat|NEG[1SBJ]', 'NEG[1SBJ]|AFF.', 'DEM|PROG', 'PROG|lie.down', 'lie.down|3SBJ.STV', '3SBJ.STV|PROG', 'PROG|behind', 'behind|starve[3sbj].', 'starve[3sbj].|next.day', 'coyote|PST', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|ocean', 'ocean|AFF', 'AFF|go.to', 'go.to|go[1sbj].', 'eat|NMLZ.P', 'NMLZ.P|find', 'find|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|ITER', 'ITER|go.over', 'go.over|3SBJ.DEF.', 'UNK|PROG', 'PROG|on.arrival', 'on.arrival|come[3sbj].', 'come[3sbj].|upon.arrival', 'upon.arrival|see', 'see|TH.IMPL[3SBJ]', 'inside|crow', 'crow|EMP', 'EMP|there', 'there|dwell[3sbj]', 'dwell[3sbj]|mud.hen', 'mud.hen|ocean.bird.', 'EMPH|leave', 'leave|3OBJ', '3OBJ|2 ...
# ----
# 6. Killer Whale
# ['DEM.DIST|toward', 'toward|above', 'above|old.man', 'old.man|be.married', 'be.married|3SBJ.STV.', '3SBJ.STV.|man', 'be.one|UNK', 'UNK|3SBJ.DEF.', '3SBJ.DEF.|EMPH', 'EMPH|CESS', 'CESS|grow.up', 'grow.up|3SBJ.DEF.', 'PST|say', 'say|3OBJ', '3OBJ|INST', 'INST|3SBJ.DEF', '3SBJ.DEF|good', 'good|AFF', 'AFF|be.fortunate', 'be.fortunate|2SBJ.STV.', 'woods|go', 'go|2SBJ', '2SBJ|gamble', 'gamble|2SBJ', '2SBJ|AFF', 'AFF|DEM.PROX', 'DEM.PROX|EMP', 'EMP|CONT', 'all|happen', 'happen|all', 'all|cl.time', 'cl.time|gamble', 'gamble|NMLZ.', 'NMLZ.|woods', 'PST|INCH', 'INCH|go.about', 'go.about|3SBJ.DEF.', '3SBJ.DEF.|elk', 'elk|PST', 'PST|kill', 'kill|TH.PASS', 'TH.PASS|3SBJ.PASS.', 'always|PST', 'PST|INCH', 'INCH|do.so', 'do.so|3SBJ.DEF.', '3SBJ.DEF.|PROG', 'PROG|kill', 'kill|3OBJ', '3OBJ|3SBJ.DEF.', 'EMP|gamble<nmlz.p>', 'gamble<nmlz.p>|win', 'win|3SBJ.DEF.', '3SBJ.DEF.|wrestle[3sbj]', 'wrestle[3sbj]|win', 'win|3SBJ.DEF.', 'PST|run.footrace[3sbj]', 'run.footrace[3sbj]|win', 'win|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|play.stick.game', 'play.stick.game|TH.IMPL[3SBJ]', 'win|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|jump<3sbj>', 'jump<3sbj>|win', 'win|3SBJ.DEF.', '3SBJ.DEF.|already', 'already|FUT', 'FUT|shoot[3sbj]', '(contend.in.archery|3SBJ.IMPL)', '3SBJ.IMPL)|win', 'win|3SBJ.DEF.', 'PST|PROG', 'PROG|shoot.arrow.into.hole.in.ground', 'shoot.arrow.into.hole.in.ground|3SBJ.INDF', '3SBJ.INDF|win', 'win|3SBJ.DEF.', 'PST|shoot.at.bunch.of.grass.in.air', 'shoot.at.bunch.of.grass.in.air|TH.INTR', 'TH.INTR|3POSS[3SBJ]', '3POSS[3SBJ]|win', 'win|3SBJ.DEF.', 'PST|shoot.sticks.into.ground[3sbj]', 'shoot.sticks.into.ground[3sbj]|win', 'win|3SBJ.DEF.', '3SBJ.DEF.|DEM.PROX', 'DEM.PROX|EMP', 'EMP|old.man', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|what.int', 'what.int|EMP', 'EMP|on.account.of', '3NEG|treat', 'treat|TH.1OBJ', 'TH.1OBJ|1OBJ[3SBJ]', '1OBJ[3SBJ]|(3NEG', '(3NEG|treat', 'treat|TH.1OBJ', 'TH.1OBJ|1OBJ[3SBJ])?', 'old.man|INCH', 'INCH|dig.hole', 'dig.hole|3OBJ', '3OBJ|3SBJ.DEF.', 'DEM|SUB', 'SUB|by.hand', 'by.hand|TH.CAUS', 'TH.CAUS|CAUS', 'CAUS|3OBJ', '3OBJ|3SBJ.DEF.', 'go.into.enclosure|by.hand', 'by.hand|TH.CAUS', 'TH.CAUS|CAUS', 'CAUS|3OBJ', '3OBJ|3SBJ.DEF.', '3NEG|know', 'know|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|woods', 'woods|go.to', 'go.to|ITER', 'ITER|go.about', 'go.about|3SBJ.DEF', 'be.one|EMP', 'EMP|sky', 'sky|SUB', 'SUB|NMLZ', 'NMLZ|3POSS', '3POSS|go', 'go|NMLZ.INF', 'NMLZ.INF|3POSS.', 'NEG.EMPH|3NEG', '3NEG|EMP', 'EMP|see', 'see|3SBJ.DEF.', '3SBJ.DEF.|DEM.DIST', 'DEM.DIST|be.light', 'PST|ITER', 'ITER|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|woods', 'woods|go.to', 'go.to|ITER', 'ITER|go.about', 'go.about|3SBJ.DEF.', 'ITER|come', 'come|3SBJ.DEF', '3SBJ.DEF|3NEG', '3NEG|EMP', 'EMP|have.temporarily', 'have.temporarily|NEG.', 'NEG.|that.time', 'ask|3OBJ', '3OBJ|INST', 'INST|3SBJ.DEF.', '3SBJ.DEF.|old.man', 'old.man|PST', 'PST|say', 'say|3SBJ.DEF', '1NEG|know', 'know|3OBJ', '3OBJ|1SBJ.SBJV.', '1SBJ.SBJV.|PST', 'PST|say', 'say|3SBJ.DEF', '1NEG|ITER', 'ITER|go.about', 'go.about|NEG[1SBJ]', 'NEG[1SBJ]|AFF.', 'AFF.|gamble', 'gamble|1SBJ', '1SBJ|AFF.', 'PST|ITER', 'ITER|be.light[nmlz]', 'be.light[nmlz]|EMP', 'EMP|gamble<3sbj>', 'gamble<3sbj>|win', 'win|TH<3SBJ>PASS.', 'wrestle|3SBJ.INDF', '3SBJ.INDF|win', 'win|TH<3SBJ>PASS.', 'TH<3SBJ>PASS.|PST', 'PST|run.footrace[3sbj]', 'win|TH.IMPL[3SBJ].', 'TH.IMPL[3SBJ].|PST', 'PST|play.stick.game', 'play.stick.game|3SBJ.INDF', '3SBJ.INDF|win', 'win|TH.IMPL[3SBJ].', 'already|FUT', 'FUT|shoot[3sbj]', 'shoot[3sbj]|win', 'win|TH.IMPL.', 'TH.IMPL.|PST', 'PST|PROG', 'PROG|shoot.at.hole', 'shoot.at.hole|3SBJ.INDF', 'win|TH.IMPL[3SBJ].', 'TH.IMPL[3SBJ].|PST', 'PST|shoot.at.grass', 'shoot.at.grass|SUB', 'SUB|3POSS', '3POSS|win', 'win|TH.IMPL.', 'PST|shoot.at.sticks[3sbj]', 'shoot.at.sticks[3sbj]|win', 'win|TH.IMPL[3SBJ].', 'no.longer|EMP', 'EMP|have', 'have|NEG[3SBJ]', 'NEG[3SBJ]|valuables.', 'valuables.|PST', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|AFF', 'PROG|be.big', 'be.big|EMP', 'EMP|work.', 'work.|DEM.PROX', 'DEM.PROX|EMP', 'EMP|old.man', 'old. ...
# ----
# 7. Above-Old-Man
# ['from|southwest', 'southwest|EMP', 'EMP|go', 'go|NMLZ.A', 'NMLZ.A|PST', 'PST|INCH', 'INCH|go', 'go|3SBJ.DEF', 'be.large|cl.round.object', 'cl.round.object|NMLZ.INF', 'NMLZ.INF|go.to', 'go.to|already', 'already|so', 'so|go', 'go|3SBJ.DEF.', 'eat|NMLZ.P', 'NMLZ.P|go.to', 'go.to|look.for[3sbj].', 'look.for[3sbj].|3NEG', '3NEG|EMP', 'EMP|see', 'see|NEG[3SBJ]', 'feast|NMLZ.INF', 'NMLZ.INF|here', 'here|(here', '(here|3POSS', '3POSS|do[3sbj]).', 'do[3sbj]).|INCH', 'INCH|near', 'near|go', 'go|3SBJ.DEF.', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', '3SBJ.DEF|madrone.berries', 'madrone.berries|already', 'already|INCH', 'INCH|fall.off[3sbj].', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|pick', 'pick|by.hand', 'by.hand|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|AFF.', 'AFF.|take', 'take|3OBJ', '3OBJ|1SBJ', 'AFF.|PROG', 'PROG|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|no.longer', 'no.longer|ITER', 'ITER|be.far', 'be.far|go', 'go|3SBJ.DEF.', 'PROG|on.arrival', 'on.arrival|come', 'come|3SBJ.DEF.', '3NEG|on.arrival', 'on.arrival|be.long.time', 'be.long.time|EMP', 'EMP|stay[3sbj].', 'stay[3sbj].|INCH', 'INCH|eat', 'eat|3SBJ.INDF.', 'PST|all', 'all|INCH', 'INCH|eat', 'eat|3SBJ.INDF.', '3SBJ.INDF.|PST', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|DEM', 'DEM|AFF', 'say|1SBJ.', '1SBJ.|PST', 'PST|think', 'think|1POSS', '1POSS|feast[nmlz]', 'feast[nmlz]|bring', 'bring|1SBJ.', 'take.hold.of|3OBJ', '3OBJ|3SBJ.INDF[NMLZ]', '3SBJ.INDF[NMLZ]|go.up.to', 'go.up.to|3OBJ', '3OBJ|3SBJ.DEF.', 'PST|take.out', 'take.out|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|be.basket.plate', 'be.basket.plate|NMLZ.A[LOC]', 'PROG|move', 'move|CAUS', 'CAUS|3SBJ.DEF.', '3SBJ.DEF.|3NEG', '3NEG|EMP', 'EMP|see', 'see|NEG[3SBJ]', 'NEG[3SBJ]|eat', 'eat|NMLZ.P.', 'be.red|cl.small.round.objects[nmlz]', 'cl.small.round.objects[nmlz]|always', 'always|DEM.DIST', 'DEM.DIST|PROG', 'PROG|PL', 'PL|dwell[nmlz]', 'always|PST', 'PST|UNK', 'UNK|look.at', 'look.at|TH.IMPL[3SBJ].', 'TH.IMPL[3SBJ].|CESS', 'CESS|eat', 'eat|3SBJ.INDF.', 'PST|darken', 'darken|3SBJ.STV.', '3SBJ.STV.|PST', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|AFF', 'AFF|CONT', 'CONT|always', 'always|stay[1sbj].', 'PST|be.light[nmlz]', 'be.light[nmlz]|PST', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', 'DEM.DIST|EMP', 'EMP|come.in', 'come.in|NMLZ.INF', 'NMLZ.INF|3POSS.', '3POSS.|salmon', 'DEM.DIST|PROG', 'PROG|carry', 'carry|3OBJ', '3OBJ|3SBJ.INDF.', '3SBJ.INDF.|southwest.young.man', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|CESS', 'CESS|PST', 'PST|know', 'know|3OBJ[1SBJ]', '3OBJ[1SBJ]|DUB', 'DUB|food', 'PROG|keep.hidden', 'keep.hidden|3SBJ.PASS.', '3SBJ.PASS.|DEM', 'DEM|AFF', 'AFF|stay[1sbj].', 'PST|EMP', 'EMP|be.afternoon[3sbj]', 'be.afternoon[3sbj]|out', 'out|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|think', 'think|3SBJ.DEF', 'go.to|see', 'see|3OBJ', '3OBJ|1SBJ', '1SBJ|AFF.', 'AFF.|PST', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', '3SBJ.DEF|there', 'there|fall[3sbj]', 'food|be.hidden', 'be.hidden|3SBJ.PASS', '3SBJ.PASS|be.wet', 'be.wet|EMP', 'EMP|PROG', 'PROG|be.shallow[nmlz].', 'PST|EMP', 'EMP|gather.wood', 'gather.wood|EMP', 'EMP|above', 'above|arrange', 'arrange|3SBJ.INDF.', '3SBJ.INDF.|PST', 'PST|think', 'think|3SBJ.DEF', 'DEM|AFF', 'AFF|stay[1sbj]', 'stay[1sbj]|then', 'then|EMP', 'EMP|go.to', 'go.to|AFF', 'AFF|then', 'then|ITER', 'ITER|go[1sbj].', 'INCH|be.dark', 'be.dark|NMLZ.INF', 'NMLZ.INF|ITER', 'ITER|INCH', 'INCH|eat', 'eat|3SBJ.INDF.', '3SBJ.INDF.|PST', 'PST|ITER', 'ITER|see', 'see|3SBJ.DEF', 'ITER|come.in', 'come.in|NMLZ.INF', 'NMLZ.INF|3POSS', '3POSS|salmon', 'salmon|come.in', 'come.in|fetch', 'fetch|3OBJ', '3OBJ|3SBJ.INDF.', 'CESS|eat', 'eat|3SBJ.INDF.', '3SBJ.INDF.|be.dark', 'be.dark|NMLZ.INF', 'NMLZ.INF|PST', 'PST|say', 'say|3SBJ.DEF', 'ITER|go[1sbj]', 'go[1sbj]|AFF.', 'AFF.|ITER', 'ITER|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|DEM.DIST', 'DEM.DIST|EMP', 'EMP|food', 'be.hidden|3SBJ<NMLZ.P>PASS', '3SBJ<NMLZ.P>PASS|PST', 'PST|break.dam', 'break.dam|3OBJ', '3OBJ|3SBJ.DEF.', 'PST|then', 'then|ITER', 'ITER|look.at', 'look.at|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|EMP', 'EMP ...
# ----
# 8. Southwest-Young-Man Looks...
# ['southwest.young.man|suddenly', 'suddenly|start.go', 'start.go|3SBJ.DEF', 'DEF|ITER', 'ITER|come', 'come|by.water', 'by.water|NMLZ.LOC', 'NMLZ.LOC|go', 'go|3SBJ.DEF.', 'PROG|on.arrival', 'on.arrival|come<nmlz.p>.', 'come<nmlz.p>.|upon.arrival', 'upon.arrival|see', 'see|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|girl', '3POSS|stay[3sbj].', 'stay[3sbj].|oh.my', 'oh.my|PST', 'PST|love', 'love|3OBJ', '3OBJ|1SBJ.', 'INCH|talk.to', 'talk.to|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|DEM.DIST', 'DEM.DIST|girl', 'girl|3NEG', '3NEG|like', 'like|3OBJ', '3OBJ|3SBJ.DEF.', 'sweat.house|then', 'then|go.into', 'go.into|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', 'PROG|hum', 'hum|do.with.mouth', 'do.with.mouth|3SBJ.INDF', '3SBJ.INDF|flute.', 'PST|witness.by.seeing', 'witness.by.seeing|SUB', 'SUB|3SBJ.INDF.', '3SBJ.INDF.|CESS', 'CESS|hum', 'hum|do.with.mouth', 'do.with.mouth|3SBJ.INDF.', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|go.to', 'go.to|be.one', 'be.one|EMP', 'EMP|bring', 'bring|1OBJ[2SBJ.IMP].', 'PST|give', 'give|3OBJ', '3OBJ|3SBJ.INDF.', '3SBJ.INDF.|INCH', 'INCH|hum', 'hum|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', 'CESS|hum', 'hum|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', '3SBJ.DEF.|ITER', 'ITER|blow', 'blow|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', 'out|go', 'go|3SBJ.DEF', '3SBJ.DEF|DEF', 'DEF|red.headed.woodpecker.', 'ITER|INCH', 'INCH|hum', 'hum|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', '3SBJ.DEF.|CESS', 'CESS|hum', 'hum|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', 'ITER|blow', 'blow|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', '3SBJ.DEF.|pileated.woodpecker', 'pileated.woodpecker|out', 'out|go', 'go|3SBJ.DEF.', 'coyote|PST', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|bring', 'bring|1<TH.IMP>OBJ[2SBJ].', 'PST|give', 'give|3OBJ', '3OBJ|3SBJ.INDF.', '3SBJ.INDF.|coyote', 'coyote|INCH', 'INCH|hum', 'hum|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', 'CESS|hum', 'hum|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', '3SBJ.DEF.|ITER', 'ITER|blow', 'blow|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', 'june.bug|out', 'out|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|ITER', 'ITER|INCH', 'INCH|hum', 'hum|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', 'ITER|CESS', 'CESS|hum', 'hum|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', '3SBJ.DEF.|ITER', 'ITER|blow', 'blow|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', 'small.bird|out', 'out|go', 'go|3SBJ.DEF.', 'DEM.DIST|girl', 'girl|PST', 'PST|INCH', 'INCH|hum', 'hum|do.with.mouth', 'do.with.mouth|3SBJ.DEF.', 'from|southwest', 'southwest|EMP', 'EMP|go.down', 'go.down|NMLZ.A', 'NMLZ.A|PST', 'PST|INCH', 'INCH|listen.to', 'listen.to|3SBJ.DEF.', 'DEM.DIST|girl', 'girl|PST', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|PST', 'PST|at.last', 'at.last|know', 'know|3OBJ[1SBJ]', 'do.to|2OBJ', '2OBJ|TH.SBJV', 'TH.SBJV|1SBJ.SBJV', '1SBJ.SBJV|AFF.', 'toward|river', 'river|then', 'then|INCH', 'INCH|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|southwest.young.man', 'INCH|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|PROG', 'PROG|at.destingation', 'at.destingation|come<3sbj.impl>.', 'go.down.in|throw', 'throw|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|flute.', 'flute.|in.middle', 'through.air|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|drift.out', 'drift.out|3SBJ.STV.', 'ITER|same.way', 'same.way|sound', 'sound|TH.IMPL.', 'TH.IMPL.|INCH', 'INCH|look.at', 'look.at|3OBJ', '3OBJ|3SBJ.DEF.', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', '3SBJ.DEF|PST', 'PST|go.ashore', 'go.ashore|float', 'float|3SBJ.STV.', '3SBJ.STV.|PST', 'PST|go', 'go|3SBJ.DEF.', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|grab', 'grab|3OBJ', '3OBJ|1SBJ.', '1SBJ.|ITER', 'ITER|go.out', 'go.out|float', 'float|3SBJ.STV.', 'INCH|follow', 'follow|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|ITER', 'ITER|see', 'see|3SBJ.DEF', 'ITER|go.ashore', 'go.ashore|float', 'float|3SBJ.STV.', '3SBJ.STV.|DEM.DIST', 'DEM.DIST|girl', 'girl|ITER', 'ITER|go.uphill', 'go.uphill|3SBJ.DEF.']
# ----
# 9. Flute
# ['small.owl|coyote', 'coyote|there', 'there|live[3sbj]', 'live[3sbj]|stay.together', 'stay.together|3SBJ.DEF.', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|no.longer', 'no.longer|travel[1sbj]', 'travel[1sbj]|AFF', 'klamath[loc]|go', 'go|1SBJ.', 'PST|go', 'go|3SBJ.DEF', '3SBJ.DEF|3NEG', '3NEG|not.much', 'not.much|be.long.time', 'be.long.time|EMP', 'EMP|stay[3sbj].', 'DEF|be.boss', 'be.boss|dwell[nmlz]', 'dwell[nmlz]|PST', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|1SG', '1SG|also', 'also|AFF', 'go|1SBJ', '1SBJ|klamath[loc].', 'klamath[loc].|PROG', 'PROG|on.arrival', 'on.arrival|come<3sbj.impl>', 'sweat.house[loc]|(UNK', '(UNK|gamble)', 'gamble)|PST', 'PST|PROG', 'PROG|on.arrival', 'on.arrival|come', 'come|3SBJ.DEF.', 'PST|on.arrival', 'on.arrival|see', 'see|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|coyote', 'coyote|3POSS', '3POSS|be.there[3sbj].', 'DEM.DIST|DEF', 'DEF|be.boss', 'be.boss|be.there[nmlz]', 'be.there[nmlz]|be.there[3sbj]', 'PST|speak.to', 'speak.to|TH.IMPL.', 'TH.IMPL.|no.longer', 'no.longer|EMP', 'EMP|be.while', 'be.while|NMLZ.INF', 'INCH|smoke', 'smoke|INST.IMPL.', 'INST.IMPL.|PST', 'PST|CESS', 'CESS|move.in', 'move.in|CAUS', 'CAUS|SUB', 'SUB|INST', 'INST|3SBJ.DEF.', 'PST|say', 'say|TH.IMPL', 'TH.IMPL|INST.IMPL', 'INST.IMPL|INDF', 'INDF|tobacco', 'tobacco|UNK', 'UNK|INT', 'INT|EMP', 'EMP|eat', 'eat|2SBJ?', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|PROG', 'PROG|suddenly', 'suddenly|eat[1sbj].', 'PST|give', 'give|3OBJ', '3OBJ|3SBJ.INDF', '3SBJ.INDF|pipe.', 'PST|EMP', 'EMP|fire', 'fire|CAUS', 'CAUS|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|CESS', 'CESS|smoke', 'smoke|INST', 'INST|3SBJ.DEF.', 'PST|ITER', 'ITER|give', 'give|3OBJ.DIR', '3OBJ.DIR|3OBJ.IND', '3OBJ.IND|3SBJ.DEF.', '3SBJ.DEF.|smoke', 'go.out|do.with.waist', 'do.with.waist|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', '3SBJ.DEF|smoke', '3POSS|go.out', 'go.out|do.with.waist', 'do.with.waist|NMLZ.INF', 'NMLZ.INF|3POSS.', '3POSS.|PST', 'PST|be.strong[3sbj]', '3POSS|be.tobacco', 'be.tobacco|SUB', 'SUB|NMLZ.INF.', 'NMLZ.INF.|PST', 'PST|CESS', 'CESS|smoke', 'smoke|INST', 'INST|3SBJ.DEF.', 'PST|say', 'say|3OBJ', '3OBJ|INST', 'INST|3SBJ.DEF', '3SBJ.DEF|1SG', '1SG|1POSS', '1POSS|pipe', '2POSS|EMP', 'EMP|fire', 'fire|CAUS', 'CAUS|3OBJ[2SBJ.IMP].', '3OBJ[2SBJ.IMP].|INCH', 'INCH|smoke', 'smoke|INST', 'INST|3SBJ.DEF', 'very|be.strong[3sbj].', 'be.strong[3sbj].|PST', 'PST|cause.pain', 'cause.pain|feel', 'feel|3SBJ.DEF.', 'PST|CESS', 'CESS|smoke', 'smoke|INST', 'INST|3SBJ.DEF.', '3SBJ.DEF.|coyote', 'coyote|PST', 'PST|say', 'say|3SBJ.DEF', 'HORT|OPT', 'OPT|pass', 'pass|3OBJ', '3OBJ|1OBJ[3SBJ].', 'PST|give', 'give|3OBJ.DIR', '3OBJ.DIR|3<TH.PASS>OBJ[3SBJ.PASS].', 'INCH|smoke', 'smoke|INST', 'INST|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|say', 'say|3SBJ.DEF', '1SG|1POSS', '1POSS|DEF', 'DEF|be.tobacco', 'be.tobacco|SUB', 'SUB|NMLZ.INF.', 'PST|ITER', 'ITER|CESS', 'CESS|smoke', 'smoke|INST', 'INST|3SBJ.DEF.', '3SBJ.DEF.|ITER', 'ITER|go', 'go|3SBJ.DEF', '3SBJ.DEF|AFF.', 'PST|ITER', 'ITER|come', 'come|3SBJ.DEF.']
# ----
# 10. Owl and Coyote Smoke
# ['UNK|PST', 'PST|kill', 'kill|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|elk.', 'EMPH|EMPH', 'EMPH|very', 'very|be.difficult[3sbj]', 'be.difficult[3sbj]|find', 'find|3OBJ', '3OBJ|NMLZ.INF', 'NMLZ.INF|3POSS.', 'INCH|think.about', 'think.about|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|where.int', 'where.int|surely', 'PST|so', 'so|go', 'go|NMLZ.INF', 'NMLZ.INF|PROG', 'PROG|ADVS', 'ADVS|dwell', 'dwell|3SBJ.STV', '3SBJ.STV|animal', 'PROG|be.many', 'be.many|3SBJ.STV.', '3SBJ.STV.|no.longer', 'no.longer|stay[3sbj]', 'stay[3sbj]|AFF', 'AFF|DEM', 'AFF|DEM.PROX', 'DEM.PROX|down', 'down|travel[1sbj].', 'travel[1sbj].|way.up', 'way.up|UNK', 'UNK|go', 'go|come', 'come|3SBJ.DEF.', 'just.ready.to|INCH', 'INCH|darken', 'darken|3SBJ.STV.', '3SBJ.STV.|fire.drill', 'PST|INCH', 'INCH|work', 'work|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|EMPH', 'EMPH|3NEG', '3NEG|make.spark', 'make.spark|3SBJ.DEF.', 'PST|CESS', 'CESS|work', 'work|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|lie.down', 'lie.down|3SBJ.STV', 'EMPH|3NEG', '3NEG|take.off', 'take.off|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|leggings.', 'leggings.|PST', 'PST|be.light[nmlz]', 'PST|up', 'up|get.up', 'get.up|3SBJ.DEF.', '3SBJ.DEF.|know', 'know|3OBJ', '3OBJ|3SBJ.DEF', 'PST|EMP', 'EMP|wear.dress', 'wear.dress|NMLZ.A.', 'NMLZ.A.|PST', 'PST|EMP', 'EMP|be.pregnant', 'be.pregnant|3SBJ.DEF.', 'no.longer|all', 'all|be.long.time', 'be.long.time|3POSS', '3POSS|PST', 'PST|EMP', 'EMP|be.cured', 'be.cured|3SBJ.DEF.', 'twin|be.male', 'be.male|3SBJ.DEF.', '3SBJ.DEF.|DEM', 'DEM|be.two', 'be.two|3SBJ.STV', 'PL|CESS', 'CESS|grow.up', 'grow.up|REFL', 'REFL|3SBJ.DEF.', '3SBJ.DEF.|toward', 'toward|3PL', 'PST|around', 'around|start.off', 'start.off|3SBJ.DEF.', '3SBJ.DEF.|UNK.LOC', 'PROG|be.one', 'be.one|EMP', 'EMP|come', 'come|3SBJ.DEF.', '3SBJ.DEF.|alder', 'alder|be.one', 'be.one|place', 'place|NMLZ.LOC', 'NMLZ.LOC|DEM', 'be.one|EMP', 'EMP|so', 'so|go', 'go|3SBJ.DEF.']
# ----
# 11. The Man Who Became a Woman
# ['from|southwest', 'southwest|EMP', 'EMP|go.down', 'go.down|3SBJ.DEF', '3SBJ.DEF|UNK', 'UNK|LOC.', 'LOC.|DEM', 'PROG|INCH', 'INCH|be.in.love', 'be.in.love|3SBJ.DEF.', '3SBJ.DEF.|hate.person.of.opposite.sex', 'hate.person.of.opposite.sex|INTS', 'INTS|3SBJ.PASS.', 'PST|know', 'know|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|how.int', 'how.int|surely', 'PST|do.so', 'do.so|TH.SBJV', 'TH.SBJV|1SBJ.SBJV.', '1SBJ.SBJV.|PST', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|AFF', 'DEM|do.so', 'do.so|1SBJ.', '1SBJ.|dog', 'dog|PST', 'PST|give.birth.to', 'give.birth.to|3SBJ.DEF.', 'PL|be.all.colors', 'be.all.colors|UNK', 'UNK|3SBJ.DEF', '3SBJ.DEF|be.ten', 'be.ten|EMP', 'EMP|3SBJ.STV.', 'no.longer|stay[3sbj]', 'stay[3sbj]|mad.river[loc]', '3POSS|around', 'around|go', 'go|NMLZ.A', 'NMLZ.A|SUB', 'SUB|3POSS', 'DEM.DIST|EMP', 'EMP|go.to', 'go.to|ITER', 'ITER|PROG', 'PROG|be.belly', 'be.belly|3SBJ.DEF.', '3SBJ.DEF.|DEM', 'elk|go.to', 'go.to|cl.elk.meat', 'cl.elk.meat|EMP', 'EMP|chase', 'chase|3OBJ', '3OBJ|NMLZ.INF.', 'PST|EMP', 'EMP|see', 'see|swim', 'swim|by.foot', 'by.foot|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|3NEG', '3NEG|think', 'think|3SBJ.DEF', 'kill|3<TH.NEG>OBJ[1SBJ].', '3<TH.NEG>OBJ[1SBJ].|DEM', 'DEM|PROG', 'PROG|on.arrival', 'on.arrival|come', 'come|3SBJ.DEF.', 'DEM|PROG', 'PROG|on.arrival', 'on.arrival|kill', 'kill|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|cut', 'cut|3OBJ', '3OBJ|3SBJ.DEF.', 'PST|EMP', 'EMP|butcher', 'butcher|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|be.right', 'be.right|EMP', 'EMP|be.small', 'be.small|divide', 'divide|3OBJ', '3OBJ|3SBJ.DEF.', 'PST|piece', 'piece|EMP', 'EMP|from.behind', 'from.behind|do', 'do|3SBJ.DEF.', 'PST|each', 'each|arrange', 'arrange|put.down', 'put.down|CAUS', 'CAUS|3SBJ.DEF.', 'PST|go.to', 'go.to|cl.elk.meat', 'cl.elk.meat|announce.elk.killed', 'announce.elk.killed|3SBJ.DEF.', '3SBJ.DEF.|DEM', 'PROG|on.arrival', 'on.arrival|come', 'come|3SBJ.DEF', '3SBJ.DEF|meat', 'meat|kill', 'kill|3OBJ[1SBJ].', 'PST|all', 'all|go.off[3sbj.pl].', 'go.off[3sbj.pl].|PST', 'PST|go.to', 'go.to|cl.elk.meat', 'cl.elk.meat|carry.elk.meat', 'carry.elk.meat|3SBJ.INDF.', 'PROG|on.arrival', 'on.arrival|all', 'all|come[3sbj].', 'come[3sbj].|INCH', 'INCH|narrate', 'narrate|3SBJ.INDF', '2SG|ITER', 'ITER|DEF', 'DEF|carry.meat', 'carry.meat|NMLZ.INF', 'NMLZ.INF|DEM.', 'PST|all', 'all|begin.carry.meat', 'begin.carry.meat|3SBJ.INDF.', 'EMPH|3NEG', '3NEG|up', 'up|CAUS', 'CAUS|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|very', 'be.heavy|3SBJ.STV', '3SBJ.STV|DEF', 'DEF|carry.meat', 'carry.meat|affect', 'affect|3POSS[NMLZ]', 'in.vain|think', 'think|3SBJ.DEF', '3SBJ.DEF|be.large', 'be.large|stand[1sbj].', 'stand[1sbj].|PST', 'PST|go', 'go|3SBJ.DEF', 'toward|southwest', 'southwest|EMP', 'EMP|go.down', 'go.down|NMLZ.A.', 'go.to|INCH', 'INCH|carry.meat', 'carry.meat|CAUS', 'CAUS|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|be.in.front.of', 'be.in.front.of|3SBJ.DEF.', 'PST|both.sides', 'both.sides|pull', 'pull|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|(PST', '(PST|pull', 'pull|3OBJ', '3OBJ|3SBJ.DEF).', 'ITER|all', 'all|go.off[3sbj.pl].', 'go.off[3sbj.pl].|PROG', 'PROG|on.arrival', 'on.arrival|ITER', 'ITER|come', 'come|3SBJ.DEF.', 'PST|EMP', 'EMP|be.pregnant', 'be.pregnant|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|EMP', 'EMP|be.cured', 'be.cured|3SBJ.DEF.', 'be.male|NMLZ.A', 'NMLZ.A|PST', 'PST|be.born[3sbj].', 'feed|cl.elk.meat', 'cl.elk.meat|3OBJ', '3OBJ|2SBJ.HORT', '2SBJ.HORT|AFF.', 'AFF.|all.time', 'all.time|PROG', 'PROG|do.so', 'do.so|2SBJ.', 'NEG.EMPH|take.care.of', 'take.care.of|3OBJ', '3OBJ|2SBJ<NEG>SBJV', '2SBJ<NEG>SBJV|people', '2POSS|DEF', 'DEF|be.born', 'be.born|CAUS', 'CAUS|NMLZ.INF.', 'NMLZ.INF.|now', 'now|AFF', 'DEM|PROG', 'PROG|take.care.of', 'take.care.of|3OBJ', '3OBJ|2SBJ.', '2SBJ.|now', 'now|DEM.PROX', 'DEM.PROX|EMP', 'EMP|person', '2POSS|ITER', 'ITER|be.born', 'be.born|CAUS', 'CAUS|NMLZ.INF.', 'NMLZ.INF.|PST', 'PST|out', 'out|throw', 'throw|3OBJ', '3OBJ|3SBJ.DEF.', 'PST|INCH', 'INCH|look.at', 'look.at|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|INCH', 'INCH|cry', 'cry|3SBJ.DEF.' ...
# ----
# 12. Southwest-Young-Man Marries
# ['once.upon.a.time|3POSS', '3POSS|INCH', 'INCH|dig.bulbs', 'dig.bulbs|3SBJ.INDF', '3SBJ.INDF|indian.potato.', 'INCH|tell', 'tell|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ.PASS]', 'INST.IMPL[3SBJ.PASS]|be.one', 'be.one|EMP', 'EMP|have.leaves', 'have.leaves|NMLZ', 'PROH|touch', 'touch|3OBJ<TH.NEG>[2SBJ.IMP].', '3OBJ<TH.NEG>[2SBJ.IMP].|DEM', 'DEM.DIST|be.two', 'be.two|EMP', 'EMP|have.leaves', 'have.leaves|NMLZ.', 'NMLZ.|DEM', 'DEM|PROG', 'PROG|dig.bulbs', 'dig.bulbs|3SBJ.IMPL', 'bay|cross.', 'cross.|UNK', 'UNK|LOC', 'LOC|PROG', 'PROG|go.to', 'go.to|gather.nuts', 'gather.nuts|TH.PASS', 'TH.PASS|3SBJ.PASS.', 'DEM|PROG', 'PROG|scold', 'scold|3OBJ<TH.SBJV>[3SBJ]', 'PROH|touch', 'touch|3OBJ<TH.NEG>[2SBJ.IMP].', '3OBJ<TH.NEG>[2SBJ.IMP].|3NEG', '3NEG|touch', 'touch|3OBJ', '3OBJ|3SBJ.DEF.', 'sometime|PROG', 'PROG|happen[nmlz]', 'happen[nmlz]|ITER', 'ITER|INCH', 'INCH|all', 'all|go.off[3sbj].', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|try', 'try|3OBJ', '3OBJ|1SBJ', '1SBJ|AFF.', 'INCH|dig.hole.in.ground', 'dig.hole.in.ground|3OBJ', '3OBJ|NMLZ', 'NMLZ|go.into', 'go.into|EMP', 'EMP|put.into.ground', 'put.into.ground|3OBJ', '3OBJ|3SBJ.DEF.', 'hear.person|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|child', 'child|3POSS', '3POSS|cry', 'cry|NMLZ', 'NMLZ|3POSS.', 'ITER|pull', 'pull|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|child', 'child|PST', 'PST|come.out.on.end.of[3sbj].', 'DEM.DIST|old.woman', 'old.woman|PST', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|2POSS', '2POSS|be.large', 'be.large|see[1sbj].', 'INCH|say.to', 'say.to|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ.PASS]', 'PROH|touch', 'touch|3OBJ<TH.NEG>[2SBJ.IMP].', '3OBJ<TH.NEG>[2SBJ.IMP].|across', 'across|carry', 'carry|3SBJ.INDF.', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|POSS', 'POSS|raise', 'raise|by.hand', 'by.hand|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|AFF.', 'EMPH|INCH', 'INCH|grow.up', 'grow.up|3SBJ.DEF.', '3SBJ.DEF.|INCH', 'INCH|go.about', 'go.about|3SBJ.DEF.', '3SBJ.DEF.|DEM.DIST', 'INCH|here.and.there', 'here.and.there|run', 'run|3SBJ.DEF.', '3SBJ.DEF.|suddenly', 'suddenly|ITER', 'ITER|come', 'come|3SBJ.DEF', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|something', 'something|see', 'see|TH<TH.N.IND>SBJV', 'TH<TH.N.IND>SBJV|1SBJ.SBJV.', 'DEM.PROX|old.woman', 'old.woman|out', 'out|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|ITER', 'ITER|come.in', 'come.in|3SBJ.DEF.', 'punch.at|cl.cylindrical', 'cl.cylindrical|3SBJ.INDF[NMLZ]', '3SBJ.INDF[NMLZ]|go.in', 'go.in|carry', 'carry|3SBJ.DEF.', 'INCH|string.bow', 'string.bow|3SBJ.DEF', '3SBJ.DEF|arrow', 'arrow|in.secret', 'in.secret|make.arrow', 'make.arrow|3SBJ.DEF.', 'PST|say.to', 'say.to|3OBJ', '3OBJ|INST', 'INST|3SBJ.DEF', 'HORT|around', 'around|ITER', 'ITER|go.to', 'go.to|look.for', 'look.for|3OBJ', '3OBJ|3SBJ.DEF.', 'PST|from.behind', 'from.behind|hand.over', 'hand.over|3OBJ', '3OBJ|3OBJ', '3OBJ|3SBJ.DEF.', '3NEG|PFV', 'PFV|be.long.time', 'be.long.time|NMLZ.INF', 'NMLZ.INF|PST', 'PST|ITER', 'ITER|come', 'come|3SBJ.DEF', '3SBJ.DEF|cotton.tail', 'PST|bring', 'bring|3SBJ.DEF.', '3SBJ.DEF.|DEM', 'DEM|PROG', 'PROG|do.so', 'do.so|3SBJ.DEF.', 'PROG|go.around', 'go.around|3SBJ.DEF.', '3SBJ.DEF.|suddenly', 'suddenly|ITER', 'ITER|come', 'come|3SBJ.DEF', '3SBJ.DEF|PST', 'PST|say', 'say|3SBJ.DEF', 'something|see', 'see|TH.SBJV', 'TH.SBJV|1SBJ.SBJV.', '1SBJ.SBJV.|old.woman', 'old.woman|deer', 'deer|DUB', 'PST|shoot', 'shoot|3OBJ', '3OBJ|2SBJ', '2SBJ|WARN.', 'WARN.|PST', 'PST|ITER', 'ITER|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|DEM', 'then|ITER', 'ITER|come', 'come|3SBJ.DEF', '3SBJ.DEF|PST', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|PST', 'PST|kill', 'kill|3OBJ[1SBJ]', 'NEG.EMPH|1NEG', '1NEG|bring', 'bring|NEG[1SBJ]', 'NEG[1SBJ]|very', 'very|be.heavy', 'be.heavy|3SBJ.STV.', 'PST|all', 'all|go.off[3sbj]', 'go.off[3sbj]|go.to', 'go.to|EMP', 'EMP|cl.elk.meat', 'cl.elk.meat|carry.meat.back.to.camp', 'carry.meat.back.to.camp|NMLZ.INF.', 'ITER|all', 'all|go.off[3sbj].', 'go.off[3sbj].|go.to', 'go.to|3NEG', '3NEG|be.much', 'be.much|be.long.time', 'be.long.time|NMLZ.INF', 'NMLZ.INF|linnet', 'PST|ITER', 'ITER|come',  ...
# ----
# 13. He-Who-Was-Dug-Up
# ...
# ----
# 43. Love Medicine
# ['toward|north', 'north|DEM', 'DEM|PROG', 'PROG|be.two', 'be.two|DEM.PROX', 'DEM.PROX|dwell', 'dwell|3SBJ.DEF', 'grow.up|REFL', 'REFL|3SBJ.DEF.', 'when|be.up', 'be.up|AUG', 'AUG|grow.up', 'grow.up|REFL', 'REFL|NMLZ.INF', 'NMLZ.INF|SUB', 'SUB|3POSS', 'INCH|say.to', 'say.to|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ.PASS]', 'INST.IMPL[3SBJ.PASS]|AFF', '2NEG|EMP', 'EMP|marry', 'marry|NEG[2SBJ].', 'NEG[2SBJ].|some.time', 'some.time|when.nmlz', 'when.nmlz|PROG', 'PROG|happen', 'PST|EMP', 'EMP|see', 'see|3SBJ.INDF', '3SBJ.INDF|man', 'man|PST', 'PST|come', 'come|NMLZ.INF', 'NMLZ.INF|SUB', 'SUB|3POSS', 'go.to|EMP', 'EMP|buy', 'buy|3SBJ.IMPL', '3SBJ.IMPL|PST', 'PST|DEM.DIST', 'DEM.DIST|girl.', 'PST|say.to', 'say.to|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ.PASS]', 'INST.IMPL[3SBJ.PASS]|DEM.DIST', 'DEM.DIST|young.man', 'what.int|relating.to', 'relating.to|already', 'already|think', 'think|TH.SBJV', 'TH.SBJV|2SBJ.SBJV', '2SBJ.SBJV|marry', 'marry|3SBJ.DEF', 'AFF?|EMPH', 'EMPH|3NEG', '3NEG|speak', 'speak|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|think', 'think|3SBJ.DEF', 'DEM.DIST|old.man', 'old.man|marry', 'marry|CAUS', 'CAUS|3OBJ[1SBJ].', 'PST|EMP', 'EMP|marry', 'marry|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|say.to', 'say.to|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ.PASS]', 'PST|go', 'go|2SBJ.HORT', '2SBJ.HORT|AFF.', 'AFF.|DEM.DIST', 'DEM.DIST|young.man', 'young.man|PST', 'PST|say', 'say|3SBJ.DEF', 'PROH|be.long.time', 'be.long.time|EMP', 'EMP|go.down[2sbj.neg].', 'PST|be.two', 'be.two|EMP', 'EMP|all.night', 'all.night|stay[3sbj].', 'stay[3sbj].|PST', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|ITER', 'ITER|go[1sbj]', 'AFF.|DEM.DIST', 'DEM.DIST|young.man', 'young.man|walk.about.outside', 'walk.about.outside|TH.INTR', 'TH.INTR|3SBJ.DEF', 'sit|3SBJ.DEF.', '3SBJ.DEF.|PROG', 'PROG|hum', 'hum|do.with.mouth', 'do.with.mouth|3SBJ.DEF', '3SBJ.DEF|flute.', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', '3SBJ.DEF|sibling', 'sibling|3POSS.', '3POSS.|PST', 'PST|ITER', 'ITER|go.in', 'go.in|3SBJ.DEF.', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|no.longer', 'no.longer|stay[1sbj]', 'stay[1sbj]|AFF.', 'AFF.|out', 'out|go', 'go|3SBJ.DEF.', 'DEM|only', 'only|cane', 'cane|3POSS', '3POSS|PST', 'PST|then', 'then|EMP', 'EMP|fetch', 'fetch|3OBJ', '3OBJ|3SBJ.DEF', 'flute|also.', 'also.|PROG', 'PROG|on.arrival', 'on.arrival|ITER', 'ITER|come', 'come|3SBJ.DEF', '3SBJ.DEF|DEM.DIST', 'DEM.DIST|woman.', 'PST|say', 'say|3SBJ.DEF', '3SBJ.DEF|where.int', 'where.int|go.to', 'go.to|go', 'go|3SBJ.DEF?', 'PST|tell', 'tell|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ.PASS]', 'INST.IMPL[3SBJ.PASS]|no.longer', 'no.longer|stay[3sbj].', 'stay[3sbj].|1SG', '1SG|also', 'AFF|no.longer', 'no.longer|stay[1sbj]', 'stay[1sbj]|PROG', 'PROG|go[1sbj]', 'go[1sbj]|AFF.', 'PST|PROG', 'PROG|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|INCH', 'INCH|sing', 'sing|3SBJ.DEF', 'DEF|sibling', 'sibling|3POSS.', '3POSS.|where', 'where|PROG', 'PROG|step', 'step|do.with.foot', 'do.with.foot|3OBJ', '3OBJ|3SBJ.DEF', '1SG|also', 'also|AFF', 'AFF|DEM', 'DEM|PROG', 'PROG|step.on[1sbj].', 'INCH|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|EMPH', 'EMPH|be.far', 'be.far|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', '3NEG|very', 'very|go[3sbj]', '3POSS|when', 'when|face', 'face|SUB', 'SUB|EMP', 'EMP|look.back.every.few.steps[3sbj].', 'look.back.every.few.steps[3sbj].|go', 'go|3SBJ.DEF.', 'DEM|INCH', 'INCH|so', 'so|sing', 'sing|3SBJ.DEF.', '3SBJ.DEF.|INCH', 'INCH|go.to', 'go.to|say.words.in.singing', 'say.words.in.singing|3SBJ.DEF', '3POSS|DEF', 'DEF|ITER', 'ITER|face', 'face|SUB', 'SUB|EMP', 'EMP|look.back.every.few.steps', 'look.back.every.few.steps|NMLZ.INF', 'NMLZ.INF|SUB', 'SUB|3POSS.', 'EMPH|be.far', 'be.far|go[3sbj].', 'go[3sbj].|just.that.far', 'just.that.far|PFV', 'PFV|UNK', 'UNK|go', 'go|3SBJ.DEF.', 'PST|think', 'think|3SBJ.DEF', '3SBJ.DEF|DEM.DIST', 'DEM.DIST|young.man', 'young.man|DEM', 'DEM|AFF', 'do.so|1SBJ', '1SBJ|so.that', 'so.that|PST', 'PST|make.mistake', 'make.mistake|TH.1OBJ', 'TH.1OBJ|1OBJ', '1OBJ|3SBJ.DEF.', 'cane|3POSS', '3POSS|PST', 'PST|put ...
# ----
# 44. The Siblings
# ['from|north', 'north|come', 'come|2SBJ', '2SBJ|in.old.days?', 'yes|from', 'from|north', 'north|around', 'around|come.from[1sbj].', 'where.int|go.to', 'go.to|go', 'go|TH.SBJV', 'TH.SBJV|2SBJ<N.IND>SBJV?', 'DEM|INT', 'INT|around', 'around|PROG', 'PROG|go', 'go|2SBJ?', 'house[loc]|visit[1sbj].', 'when.int|AFF', 'then|EMP', 'EMP|go', 'go|TH.SBJV', 'TH.SBJV|2SBJ<N.IND>SBJV?', 'very.soon|go', 'go|1SBJ', '1SBJ|AFF.', 'how.long.int|AFF', 'go.to|then', 'then|PFV', 'PFV|INCH', 'INCH|stay', 'stay|2SBJ<N.IND>SBJV?', 'DEM|AFF', 'AFF|around', 'around|ITER', 'ITER|come.so[1sbj].', 'ITER|come', 'come|1SBJ', '1SBJ|must', 'must|on.arrival', 'on.arrival|ITER', 'ITER|stay[1sbj].', 'PROG|AFF', 'AFF|go.to.work', 'go.to.work|3OBJ', '3OBJ|1SBJ.', 'how.long.int|CESS', 'PROG|then', 'then|PFV', 'PFV|go.to.work', 'go.to.work|3OBJ', '3OBJ|2SBJ.SBJV?', '1NEG|know', 'know|3OBJ', '3OBJ|2SBJ<NEG>SBJV.', 'be.one|EMP', 'EMP|cl.day', 'cl.day|PROG', 'PROG|go.to', 'go.to|work', 'work|3OBJ[2SBJ]?', 'how.much.int|around', 'around|give', 'give|TH.1OBJ', 'TH.1OBJ|1OBJ', '1OBJ|3OBJ[2SBJ]?', 'be.two|cl.flat.round', 'cl.flat.round|UNK[NMLZ].', 'where|possess.temporarily', 'possess.temporarily|3OBJ', '3OBJ|REFL[1SBJ].', 'PROG|AFF', 'AFF|CESS', 'CESS|work', 'work|3OBJ', '3OBJ|1SBJ.', '1SBJ.|PROG', 'PROG|hire', 'hire|TH.1OBJ', 'TH.1OBJ|1OBJ[3SBJ].', 'PROG|AFF', 'AFF|go.to.work', 'go.to.work|3OBJ[1SBJ].', '3OBJ[1SBJ].|DEF', 'DEF|work', 'work|NMLZ.INF', '3NEG|be.much', 'be.much|be.large', 'be.large|3SBJ.STV.', '3SBJ.STV.|PROG', 'PROG|AFF', 'FUT|soon', 'soon|CESS', 'CESS|1SBJ.SBJV', 'like|3OBJ.PERS', '3OBJ.PERS|2OBJ[1SBJ]', '2OBJ[1SBJ]|2POSS', '2POSS|see', 'see|2OBJ', '2OBJ|1SBJ.SBJV.', 'talk.to|2OBJ[1SBJ]', '2OBJ[1SBJ]|AFF.', 'AFF.|FUT', 'FUT|visit', 'visit|2SBJ.IMP', '2SBJ.IMP|AFF.', 'DEM|AFF', 'AFF|go.to', 'go.to|go[1sbj].', 'go[1sbj].|PROG', 'PROG|AFF', 'speak.to|UNK', 'UNK|2OBJ[1SBJ].', 'how.long.int|AFF', 'AFF|then', 'then|EMP', 'EMP|come', 'come|2SBJ<N.IND>SBJV?', 'somewhere|around', 'around|happen.', 'happen.|long.ago', 'long.ago|money', '1POSS|lend', 'lend|3OBJ.PERS', '3OBJ.PERS|NMLZ.INF', 'NMLZ.INF|DEM', 'PROG|think', 'think|CESS', 'CESS|work', 'work|UNK', 'UNK|3SBJ.DEF', 'relating.to|EMP', 'EMP|speak', 'speak|3SBJ.INDF', '3SBJ.INDF|ITER', 'ITER|call.for', 'call.for|3OBJ[1SBJ]', 'AFF.|oh.my!', 'oh.my!|be.glad', 'be.glad|3OBJ[1SBJ]', '3OBJ[1SBJ]|1POSS', '1POSS|money', '1POSS|ITER', 'ITER|see', 'see|1SBJ.SBJV.']
# ----
# 45. Informal Conversation 1
# ['where.int|go.to', 'go.to|go', 'go|TH.SBJV', 'TH.SBJV|2SBJ<N.IND>SBJV?', 'PROG|around', 'around|news[1sbj]', 'news[1sbj]|DEM', 'DEM|wherever', 'wherever|go[1sbj].', 'something|NEG.EMPH', 'NEG.EMPH|happen[3sbj].', 'happen[3sbj].|single.one', 'NEG.EMPH|PROG', 'PROG|be.ill', 'be.ill|SUB', 'SUB|3SBJ.STV.', '3SBJ.STV.|be.good', 'be.good|CONT', 'PROG|happen[3sbj].', 'in.the.past|1POSS', '1POSS|hear.news', 'hear.news|3OBJ', '3OBJ|NMLZ.INF', '3POSS|PROG', 'PROG|fight', 'fight|3SBJ.IMPL.', 'DEM|fight', 'fight|SUB', 'SUB|DIM', 'DIM|3SBJ.IMPL.', '2SG|INT', 'INT|know', 'know|3OBJ', '3OBJ|2SBJ?', '2SBJ?|in.the.past', 'hear.news|3OBJ[1SBJ]', '3OBJ[1SBJ]|person', 'PROG|3POSS', '3POSS|hurt', 'hurt|3SBJ.PASS.', 'yes|man', 'man|shoot', 'shoot|INTS', 'INTS|3SBJ.PASS.', '1SG|also', 'also|in.the.past', 'in.the.past|DEM', 'DEM|around', 'around|listen.to[3sbj].', 'PROG|tell', 'tell|1OBJ[3SBJ]', '1OBJ[3SBJ]|PST', 'PST|EMP', 'EMP|miss', 'miss|3SBJ.PASS.']
# ----
# 46. Informal Conversation 2
# ['1SG|PST', 'PST|shoot', 'shoot|3OBJ', '3OBJ|1SBJ.', '1SBJ.|PST', 'PST|kill', 'kill|3OBJ[1SBJ].', 'EMPH|be.fat', 'be.fat|3SBJ.DEF?', 'be.thin|3SBJ.DEF.', 'DEM|INT', 'INT|relating.to', 'relating.to|only', 'DEM.DIST|see', 'see|NMLZ.INF?', 'in.vain|be.many', 'be.many|see', 'see|3OBJ[1SBJ].', '3OBJ[1SBJ].|no.longer', 'no.longer|EMP', 'EMP|see', 'see|3SBJ.INDF', '3POSS|cartridge', 'cartridge|DEM', 'DEM|3NEG', '3NEG|be.one', 'be.one|cl.large.round.', 'DEM|only', 'only|be.one', 'be.one|EMP', 'EMP|shoot[1sbj].', '1SG|AFF', 'AFF|DEM', 'DEM|go.to', 'go.to|go[1sbj].', 'animal|relating.to', 'relating.to|be.many', 'be.many|3SBJ.STV', 'INCH|kill', 'kill|3OBJ', '3OBJ|2SBJ', '2SBJ|somewhere', 'think|2SBJ.SBJV', '2SBJ.SBJV|be.so.many', 'be.so.many|3OBJ[2SBJ].', 'PROG|EMPH', 'EMPH|1NEG', '1NEG|appear[3sbj].', 'sometime|go.to', 'go.to|INDF', 'INDF|happen[nmlz]', 'happen[nmlz]|DEM', 'DEM|AFF', 'go.to|ITER', 'ITER|go[1sbj]', 'go[1sbj]|3POSS', '3POSS|tracks', 'tracks|3POSS', 'be.many|see', 'see|3OBJ[1SBJ].', '3OBJ[1SBJ].|be.good', 'be.good|EMP', 'EMP|happen[3sbj]', 'happen[3sbj]|very', 'like|3OBJ', '3OBJ|1SBJ', '1SBJ|DEM', 'DEM|1POSS', '1POSS|PROG', 'PROG|go.about', 'go.about|1SBJ.']
# ----
# 47. Informal Conversation 3
# ['PST|CESS', 'CESS|speak.to', 'speak.to|TH.1OBJ', 'TH.1OBJ|RECP', 'RECP|3SBJ.DEF', '3SBJ.DEF|3PL.', '3PL.|DEM', '3POSS|say', 'say|NMLZ.INF', 'NMLZ.INF|SUB', 'SUB|3POSS', '3POSS|PST', 'PST|all', 'all|CESS', 'CESS|speak', 'speak|3SBJ.INDF.', 'DEM.DIST|be.so.many', 'be.so.many|3SBJ.STV[NMLZ]', '3SBJ.STV[NMLZ]|PROG', 'PROG|smoke', 'smoke|INST', 'INST|3SBJ.DEF', '3SBJ.DEF|pipe', 'PST|DEM.DIST', 'DEM.DIST|put.away', 'put.away|3SBJ.IMPL.', '3SBJ.IMPL.|PROG', 'PROG|EMPH', 'EMPH|3NEG[NMLZ]', '3PL|smoke', 'smoke|INST.IMPL[3SBJ.PASS].', 'INST.IMPL[3SBJ.PASS].|3POSS', '3POSS|INCH', 'INCH|make.speech', 'make.speech|3SBJ.INDF', 'single.one|3NEG', '3NEG|PROG', 'PROG|3POSS', '3POSS|move', 'move|sit', 'sit|NEG.', 'NEG.|say', 'say|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ]', '(PROG|say', 'say|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ])', 'INST.IMPL[3SBJ])|children', 'children|PROG', 'PROG|suddenly', 'suddenly|cry', 'cry|3SBJ.DEF.', 'in.the.midst.of|make.speech', 'make.speech|3SBJ.INDF', '3SBJ.INDF|be.allowable[3sbj]', '3POSS|be.parent[nmlz]', 'be.parent[nmlz]|PROG', 'PROG|out', 'out|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|DEM', 'ITER|go', 'go|3SBJ.DEF.', '3SBJ.DEF.|3POSS', '3POSS|PROG', 'PROG|ITER', 'ITER|come', 'come|NMLZ.INF', 'NMLZ.INF|SUB', 'SUB|3POSS', 'PROG|adorn.oneself', 'adorn.oneself|TH.1OBJ', 'TH.1OBJ|REFL', 'REFL|3SBJ.DEF', '3SBJ.DEF|PST', 'PST|all', 'all|take.off', 'take.off|3OBJ', '3OBJ|3SBJ.DEF.', '(PROG|adorn.oneself', 'adorn.oneself|TH.1OBJ', 'TH.1OBJ|REFL', 'REFL|3SBJ.DEF', '3SBJ.DEF|PST', 'PST|all', 'all|take.off', 'take.off|3OBJ', '3OBJ|3SBJ.DEF', 'DEM.DIST|PROG', 'PROG|ITER', 'ITER|come', 'come|NMLZ.INF', 'NMLZ.INF|SUB', 'SUB|3POSS', 'DEM.DIST|PFV', 'PFV|go.down', 'go.down|go', 'go|3SBJ.DEF).', '3SBJ.DEF).|DEM', 'DEM|3PL', 'PROG|do.so', 'do.so|3SBJ.DEF.']
# ----
# 48. Fox Text 1
# ['DEM.DIST|be.so', 'be.so|NMLZ.P', 'NMLZ.P|know', 'know|3OBJ', '3OBJ|3SBJ.DEF', '3SBJ.DEF|DEM', 'hire|TH.PASS', 'TH.PASS|3SBJ.PASS', '3SBJ.PASS|medicine', '3POSS|make', 'make|NMLZ.INF', 'NMLZ.INF|SUB', 'SUB|3POSS.', '3POSS.|attack', 'attack|NMLZ.INF', 'NMLZ.INF|DEM', 'medicine|PROG', 'PROG|make', 'make|3OBJ', '3OBJ|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|DEM.DIST', 'DEM.DIST|bones', 'bones|3POSS', 'INDF|bones.dim', 'bones.dim|NMLZ.A', 'NMLZ.A|DEM', 'DEM|medicine', 'PROG|make', 'make|3OBJ', '3OBJ|3OBJ', '3OBJ|3SBJ.DEF.', '3SBJ.DEF.|all.the.way', 'all.the.way|house', 'PROG|where', 'where|separately', 'separately|build', 'build|CAUS', 'CAUS|3SBJ.INDF.', '3SBJ.INDF.|attack', 'attack|NMLZ.INF', 'DEM.DIST|PROG', 'PROG|lie', 'lie|CAUS', 'CAUS|3SBJ.INDF.', 'PROG|around', 'around|where', 'where|bring.from', 'bring.from|3SBJ.INDF', '3SBJ.INDF|attack', 'attack|NMLZ.INF.', 'NMLZ.INF.|DEM', 'where|then', 'then|ITER', 'ITER|go.about', 'go.about|3SBJ.DEF.', '3SBJ.DEF.|PROG', 'PROG|[wear]breech.cloth', '[wear]breech.cloth|3SBJ.DEF', 'only|otherwise', 'otherwise|PROG', 'PROG|be.naked', 'be.naked|3SBJ.DEF.', 'DEM.DIST|PFV', 'PFV|ITER', 'ITER|go.in', 'go.in|NMLZ.INF', 'NMLZ.INF|SUB', 'SUB|3POSS', '3POSS|PST', 'PST|EMP', 'EMP|see', 'see|3SBJ.DEF', 'another|attack', 'attack|NMLZ.INF', 'NMLZ.INF|3POSS', '3POSS|where', 'where|AUG', 'AUG|lie[3sbj].', 'lie[3sbj].|DEM', 'around|happen[3sbj]', 'happen[3sbj]|PL', 'PL|some', 'some|be.full.of.holes', 'be.full.of.holes|cl.surface[3sbj]', 'hole|relating.to.', 'relating.to.|DEM.DIST', 'DEM.DIST|PROG', 'PROG|all', 'all|see', 'see|3OBJ', '3OBJ|NMLZ', 'NMLZ|SUB', 'SUB|3POSS', '3POSS|toward', 'toward|east', 'do|stand.up', 'stand.up|3SBJ.STV.', '3SBJ.STV.|in.the.past', 'in.the.past|CONT', 'CONT|DEM.DIST', 'DEM.DIST|INCH', 'INCH|so', 'so|sing', 'sing|3SBJ.INDF', 'CONT|PST', 'PST|PROG', 'PROG|so', 'so|sing', 'sing|3SBJ.INDF.', '3SBJ.INDF.|DEM.DIST', 'DEM.DIST|attack', 'attack|NMLZ.INF', 'PROG|tell', 'tell|TH.IMPL', 'TH.IMPL|INST.IMPL[3SBJ.PASS]', 'INST.IMPL[3SBJ.PASS]|PROH', 'PROH|cry[2sbj].', 'cry[2sbj].|cry', 'cry|3SBJ.DEF', 'tell.what.one.sees.doctoring[3sbj.pass]|PROG', 'PROG|die[3sbj].', 'PROG|say[3sbj.pass]', 'say[3sbj.pass]|believe[3sbj]', 'believe[3sbj]|PROG', 'PROG|some', 'some|cry', 'cry|CAUS', 'CAUS|3SBJ.INDF.', '1SG|ADVS', 'ADVS|PROG', 'PROG|say[3sbj]', 'say[3sbj]|be.sure.of', 'be.sure.of|3SBJ.INDF', '3SBJ.INDF|say[3sbj]', 'PROG|PST', 'PST|PL', 'PL|die[3sbj]', 'die[3sbj]|before', 'before|DEM.DIST', 'DEM.DIST|PL', 'PL|cry', 'cry|UNK', 'UNK|3SBJ.INDF.', 'in.the.past|DEM.DIST', 'DEM.DIST|NEG.EMPH', 'NEG.EMPH|PL', 'PL|cry', 'cry|UNK', 'UNK|3SBJ.INDF', 'PST|ITER', 'ITER|all', 'all|be.cured', 'be.cured|3SBJ.DEF.', '3SBJ.DEF.|single.one', 'single.one|3NEG', '3NEG|3PL', 'PL|have.disease', 'have.disease|3SBJ.DEF.', '3SBJ.DEF.|PST', 'PST|ITER', 'ITER|all', 'all|very', 'very|be.cured', 'be.cured|3SBJ.DEF', '(PST|ITER', 'ITER|thoroughly', 'thoroughly|be.cured', 'be.cured|NMLZ.INF', 'NMLZ.INF|SUB', 'SUB|3POSS)', '3POSS)|CONT', '3PL.|3POSS', '3POSS|bones', 'bones|3POSS', '3POSS|PST', 'PST|AUG', 'AUG|be.long[3sbj].', 'then|ITER', 'ITER|out', 'out|EMP', 'EMP|come.so', 'come.so|grow', 'grow|REFL', 'REFL|3SBJ.DEF.']

# %%
list(reichard.keys())[14]
# Out:
# '14. The Brother Who Became A...'

# %%
getWordPairsFromText(reichard['14. The Brother Who Became A...'])
# Out:
# ['once.upon.a.time|man',
#  'man|all',
#  'all|be.two',
#  'be.two|EMP',
#  'EMP|be.born[3sbj.pass].',
#  'be.born[3sbj.pass].|all.the.time',
#  'woods|3POSS',
#  '3POSS|go',
#  'go|NMLZ.P.',
#  'NMLZ.P.|dog',
#  'PROG|OPT',
#  'OPT|hear.person',
#  'hear.person|3OBJ[1SBJ]',
#  '3OBJ[1SBJ]|DEF',
#  'DEF|chase',
#  'chase|NMLZ.INF',
#  'NMLZ.INF|3POSS.',
#  '3POSS.|all.the.time',
#  'PROG|hum',
#  'hum|NMLZ.INF.',
#  'NMLZ.INF.|DEM',
#  'DEM|PROG',
#  'PROG|so',
#  'so|do[3sbj]',
#  'do[3sbj]|woods',
#  'woods|relating.to',
#  'PROG|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|again.and.again',
#  'again.and.again|ITER',
#  'ITER|hum',
#  'hum|NMLZ.INF',
#  'OPT|hear.person',
#  'hear.person|3SOBJ[1SBJ].',
#  '3SOBJ[1SBJ].|PROG',
#  'PROG|go',
#  'go|3SBJ.DEF.',
#  '3NEG|be.far',
#  'be.far|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|UNK',
#  'UNK|look.back.every.few.steps',
#  'look.back.every.few.steps|3SBJ.DEF',
#  'EMPH|3NEG',
#  '3NEG|EMP',
#  'EMP|see',
#  'see|3SBJ.DEF',
#  '3SBJ.DEF|sibling',
#  'sibling|3POSS.',
#  'be.well|3NEG',
#  '3NEG|feel',
#  'feel|3SBJ.DEF.',
#  '3SBJ.DEF.|DEM',
#  'DEM|PST',
#  'PST|go.to',
#  'go.to|upright',
#  'upright|sit',
#  'sit|3SBJ.DEF.',
#  'tó|tol',
#  'tol|ił.',
#  'ił.|ko',
#  'ko|łowi',
#  'łowi|lág',
#  'lág|ił.',
#  'ił.|čuwowokós',
#  'ha|wél',
#  'wél|ił',
#  'ił|wóyic',
#  'wóyic|ha',
#  'ha|túw',
#  'túw|akw',
#  'akw|ahl',
#  'hi|no',
#  'no|kú',
#  'kú|to',
#  'to|wał',
#  'wał|tám',
#  'tám|ił.',
#  'ił.|čuwó',
#  'hih|kwi',
#  'kwi|d',
#  'd|átol',
#  'átol|ił.',
#  'ił.|hi',
#  'hi|ya',
#  'ya|wétw',
#  'wétw|ił.',
#  'ko|núk',
#  'núk|ak',
#  'ak|púšoth',
#  'púšoth|um',
#  'um|wóyic',
#  'hu|kówelaw',
#  'kówelaw|ekw',
#  'ekw|ahl.',
#  'ahl.|ku',
#  'ku|lúw',
#  'lúw|ił.',
#  'ił.|hi',
#  'hi|kú',
#  'kú|lag',
#  'lag|ił.',
#  'to|ku',
#  'ku|lúw',
#  'lúw|ił.',
#  'ił.|kwi',
#  'kwi|kú',
#  'kú|katow',
#  'katow|ił.',
#  'łkó|wi',
#  'wi|ye',
#  'ye|ko',
#  'ko|phł',
#  'phł|úih.',
#  'úih.|hi',
#  'hi|kó',
#  'kó|phł',
#  'phł|úih.',
#  'tówadákhad|ahl',
#  'ahl|hi',
#  'hi|túm',
#  'túm|ił',
#  'ko|la',
#  'la|wá',
#  'wá|gadútw',
#  'gadútw|ił.',
#  'ił.|kit',
#  'kit|ápal',
#  'ápal|uyh.',
#  'ku|thig',
#  'thig|átol',
#  'átol|ił.',
#  'ił.|kedú',
#  'kedú|to',
#  'to|ku',
#  'ku|tékwhłim.',
#  'wólok|ku',
#  'ku|ków',
#  'ków|adol',
#  'adol|wónokw',
#  'wo|kú',
#  'kú|lol.',
#  'lol.|čéčhočh',
#  'čéčhočh|hi',
#  'hi|níyab',
#  'níyab|áw',
#  'áw|ad.',
#  'ku|lág',
#  'lág|ił.',
#  'ił.|ku',
#  'ku|dawáłór',
#  'dawáłór|wónokw',
#  'bo|ku',
#  'ku|lól.',
#  'lól.|tełto',
#  'tełto|tó',
#  'tó|nagadak',
#  'wud|a',
#  'a|wóyic',
#  'wóyic|kí',
#  'kí|tokw',
#  'tokw|ił.',
#  'ił.|hi',
#  'hi|nóg',
#  'nóg|ił',
#  'kítko|ko',
#  'ko|ku',
#  'ku|lół',
#  'lół|ił.',
#  'ił.|kítko',
#  'kítko|hi',
#  'hi|kuc',
#  'kuc|étol',
#  'étol|ił.',
#  'ku|lúw',
#  'lúw|ił',
#  'ił|hi',
#  'hi|ku',
#  'ku|kwé',
#  'kwé|kł',
#  'kł|om',
#  'om|ił',
#  'hu|tokw.',
#  'tokw.|hi',
#  'hi|kú',
#  'kú|dawáłor',
#  'dawáłor|wónokw',
#  'bó|ku',
#  'ku|lol.',
#  'lol.|hí',
#  'hí|ku',
#  'ku|luh.',
#  'kwí|kł',
#  'kł|om',
#  'om|ił',
#  'ił|kud',
#  'kud|o',
#  'o|wóyic',
#  'to|tékwhłihm.',
#  'tékwhłihm.|kwi',
#  'kwi|kátow',
#  'kátow|ił.',
#  'ił.|hi',
#  'hi|kó',
#  'kó|pł',
#  'pł|úih.',
#  'ko|kátaw',
#  'kátaw|ił.',
#  'ił.|hi',
#  'hi|nók',
#  'nók|ił',
#  'šuwó|to',
#  'to|dákw',
#  'dákw|eh.',
#  'eh.|thíg',
#  'thíg|atol',
#  'atol|ił',
#  'ił|katow',
#  'katow|úlaw',
#  'úlaw|ił.',
#  'kit|án',
#  'án|aw',
#  'aw|ákw',
#  'ákw|ahl',
#  'ahl|čiwał',
#  'hi|kú',
#  'kú|wu',
#  'wu|thíg',
#  'thíg|atol',
#  'atol|ił.',
#  'ił.|hi',
#  'hi|nóg',
#  'nóg|ił',
#  'šuwa|to',
#  'to|dákwh',
#  'dákwh|eh',
#  'eh|łe',
#  'łe|kó',
#  'kó|la',
#  'la|bół',
#  'bół|ił.',
#  'hih|thig',
#  'thig|átol',
#  'átol|ił',
#  'ił|kháwoh',
#  'kháwoh|to',
#  'to|kátow',
#  'kátow|ił.',
#  'ko|la',
#  'la|lúwetw',
#  'lúwetw|ił.',
#  'ił.|hí',
#  'hí|dawáłor',
#  'dawáłor|thig',
#  'thig|átol',
#  'átol|ił.',
#  'mul|ókw',
#  'ókw|hi',
#  'hi|t',
#  't|átol',
#  'átol|ił',
#  'ił|łé',
#  'łé|ko',
#  'ko|la',
#  'la|wél',
#  'wél|ił.',
#  'kátow|ił',
#  'ił|ko',
#  'ko|la',
#  'la|wél',
#  'wél|uh.',
#  'uh.|hi',
#  'hi|tówíl',
#  'tówíl|im',
#  'im|ut',
#  'ut|ił',
#  'wew|ahl.',
#  'ahl.|hi',
#  'hi|yél',
#  'yél|ił',
#  'ił|kadá',
#  'kadá|la',
#  'la|wél',
#  'wél|ah.',
#  'ku|thig',
#  'thig|átol',
#  'átol|ił.',
#  'ił.|kowa',
#  'kowa|dáłak',
#  'dáłak|aw',
#  'aw|ił',
#  'ił|kítko.',
#  'kó|łowi',
#  'łowi|lág',
#  'lág|ił',
#  'ił|púšuk',
#  'púšuk|ił',
#  'ił|tó',
#  'tó|lekwhl',
#  'lekwhl|uh.',
#  'ko|łówi',
#  'łówi|lág',
#  'lág|ił',
#  'ił|hi',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił',
#  'ił|hu',
#  'hu|wéleł',
#  'wéleł|ahl.',
#  'ko|łówi',
#  'łówi|lág',
#  'lág|ił',
#  'ił|pušúk',
#  'pušúk|ił',
#  'ił|tó',
#  'tó|lekwhl',
#  'lekwhl|uh.',
#  'hi|kwe',
#  'kwe|kł',
#  'kł|óm',
#  'óm|ił',
#  'ił|hu',
#  'hu|tám',
#  'tám|ekw',
#  'ekw|ahl.',
#  'hís|tohl',
#  'tohl|ił',
#  'ił|tišk',
#  'tišk|óm',
#  'óm|aw',
#  'aw|ał',
#  'khú|wal',
#  'wal|ós',
#  'ós|ak.',
#  'ak.|kuc',
#  'kuc|kedó',
#  'kedó|lok',
#  'lok|ehl.',
#  'ehl.|čiwał',
#  'čiwał|kito',
#  'kúwil|wó',
#  'wó|ko',
#  'ko|lok',
#  'lok|a<h>n.',
#  'ho|kád',
#  'kád|tokw',
#  'tokw|á',
#  'á|kon',
#  'kon|aw',
#  'aw|eł',
#  'eł|il.',
#  'il.|čuwowałwáł',
#  'kalók|tol.',
#  'tol.|wónokw',
#  'wónokw|ko',
#  'ko|šu',
#  'šu|kú',
#  'kú|lol',
#  'lol|eh.',
#  'kówał|khi',
#  'khi|kú',
#  'kú|díyab',
#  'díyab|ob',
#  'ob|uhm.',
#  'šu|ku',
#  'ku|wátitw',
#  'wátitw|ów',
#  'ów|ar',
#  'ar|ag',
#  'ag|ko',
#  'ko|woł',
#  'khi|kú',
#  'kú|wał',
#  'wał|aw',
#  'aw|eg.',
#  'eg.|ku',
#  'ku|lóg',
#  'lóg|it',
#  'it|kítko.',
#  'hi|kú',
#  'kú|lág',
#  'lág|ił.',
#  'ił.|wónokw',
#  'wónokw|kó',
#  'kó|ku',
#  'ku|lol',
#  'lol|ił.',
#  'tełto|tó',
#  'tó|nágadak',
#  'nágadak|wónokw',
#  'wónokw|hí',
#  'hí|wo',
#  'wo|ku',
#  'ku|lól',
#  'lól|ił.',
#  'łé|ko',
#  'ko|lo',
#  'lo|wél',
#  'wél|ił.',
#  'ił.|ku',
#  'ku|lág',
#  'lág|ił.',
#  'kó|ku',
#  'ku|lol',
#  'lol|ił.',
#  'ił.|bew',
#  'bew|i',
#  'i|kulókh',
#  'kulókh|awel',
#  'awel|uyh',
#  'tó|gadel',
#  'gadel|hí',
#  'hí|ya',
#  'ya|bótok.',
#  'bótok.|kalákh',
#  'kalákh|a',
#  'a|lol',
#  'lol|ił.',
#  'tełto|tó',
#  'tó|nagadak',
#  'nagadak|bó',
#  'bó|ku',
#  'ku|lol',
#  'lol|kítko.',
#  'ku|kó',
#  'kó|la',
#  'la|wél',
#  'wél|ił.',
#  'ił.|ku',
#  'ku|lág',
#  'lág|ił.',
#  'khúno|ku',
#  'ku|liyo',
#  'liyo|kalók',
#  'kalók|tokw',
#  'tokw|hi',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił',
#  'tó|gadel',
#  'gadel|hi',
#  'hi|kowo',
#  'kowo|wótog.',
#  'wótog.|dónotwulúyuket',
#  'hi|y',
#  'y|etháw',
#  'etháw|onihl',
#  'onihl|lág',
#  'lág|ił',
#  'ił|kítko.',
#  'wo|lóg',
#  'lóg|ethám',
#  'ethám|ut',
#  'ut|at.',
#  'at.|hi',
#  'hi|wa',
#  'wa|lóg',
#  'lóg|ił',
#  'thám|ut',
#  'ut|ił.',
#  'ił.|to',
#  'to|lił',
#  'lił|élot',
#  'élot|ko',
#  'ko|wólokw',
#  'šuhdiyó|gálew',
#  'gálew|et.',
#  'et.|kú',
#  'kú|lág',
#  'lág|ił.',
#  'tó|ku',
#  'ku|lúw',
#  'lúw|ił.',
#  'ił.|yo',
#  'yo|kósw',
#  'kósw|a',
#  'a|sísw',
#  'sísw|ek',
#  'hawégadak|hi',
#  'hi|łák',
#  'łák|ulaw',
#  'ulaw|ónihl.',
#  'łák|u',
#  'u|wis',
#  'wis|ónihl.',
#  'ónihl.|kówa',
#  'kówa|dawáłor',
#  'šudiyó|galaw',
#  'galaw|ił.',
#  'ił.|hi',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił',
#  'sisw|ágadak.',
#  'ágadak.|hi',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił',
#  'ił|hi',
#  'hi|ta',
#  'ta|wés',
#  'wés|onihl.',
#  'hi|łág',
#  'łág|ił.',
#  'ił.|hí',
#  'hí|ta',
#  'ta|l',
#  'l|ab',
#  'ab|út',
#  'út|ił.',
#  'tó|wi',
#  'wi|kł',
#  'kł|óm',
#  'óm|ił.',
#  'ił.|hi',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił',
#  'ił|hawégadak.',
#  'ku|lág',
#  'lág|ił.',
#  'ił.|tó',
#  'tó|ku',
#  'ku|lúw',
#  'lúw|ił.',
#  'ił.|hi',
#  'hi|nóg',
#  'nóg|ił',
#  'bo|wałé',
#  'wałé|ku',
#  'ku|lol',
#  'lol|kítko.',
#  'kítko.|ko',
#  'ko|łowi',
#  'łowi|lág',
#  'lág|ił.',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił',
#  'ił|mélakw',
#  'mélakw|ha',
#  'ha|wéleł',
#  'wéleł|ahl.',
#  'ahl.|khúno',
#  'tokátkotágadak|či',
#  'či|tokt',
#  'tokt|ho',
#  'ho|kós',
#  'hih|duw',
#  'duw|ił.',
#  'ił.|tó',
#  'tó|tol',
#  'tol|ił.',
#  'ił.|mélakw',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił.',
#  'ił.|łe',
#  'łe|kó',
#  'kó|soból',
#  'soból|ew',
#  'ew|ił.',
#  'tó|tol',
#  'tol|ił.',
#  'ił.|ko',
#  'ko|łówi',
#  'łówi|lág',
#  'lág|ił.',
#  'ił.|kwołwał',
#  'hi|kú',
#  'kú|wél',
#  'wél|ił',
#  'ił|mélakw.',
#  'łe|ko',
#  'ko|soból',
#  'soból|ew',
#  'ew|ił.',
#  'kwi|thig',
#  'thig|átol',
#  'átol|ił',
#  'ił|bómel',
#  'bómel|aw',
#  'aw|ókw.',
#  'kwi|kł',
#  'kł|óm',
#  'óm|ił',
#  'ił|čečhóčh',
#  'čečhóčh|tu',
#  'tu|mige',
#  'mige|sísw',
#  'sísw|apt',
#  'tu|mige',
#  'mige|balúyab',
#  'balúyab|apt',
#  'apt|hu',
#  'hu|madón',
#  'madón|ahl',
#  'tu|šuyag',
#  'šuyag|íth',
#  'íth|ad.',
#  'ad.|bokos',
#  'bokos|hi',
#  'hi|swól',
#  'swól|ew',
#  'ew|ił.',
#  'hi|níyab',
#  'níyab|úm',
#  'úm|ił.',
#  'ił.|th',
#  'th|óm',
#  'óm|ił.',
#  'ił.|hi',
#  'hi|yákw',
#  'th|ab',
#  'ab|ił.',
#  'ił.|kówo',
#  'kówo|púw',
#  'púw|ił.',
#  'ił.|hi',
#  'hi|rú',
#  'rú|lap.',
#  'kó|phł',
#  'phł|ił.',
#  'ił.|kit',
#  'kit|ápal',
#  'ápal|akw',
#  'akw|ahl',
#  'ku|kikátol',
#  'kikátol|ił.',
#  'ił.|to',
#  'to|ku',
#  'ku|lúw',
#  'lúw|ił.',
#  'ił.|kič',
#  'hił|hi',
#  'hi|lócuw',
#  'lócuw|ił.']

# %%
all_authors_wordpairs = kroeber_wordpairs + reichard_wordpairs + teeter_wordpairs

# %%
all_biword_frequency = countFrequencyWordPairs(all_authors_wordpairs)

# %%
word_pair_frequency = pd.DataFrame.from_dict(all_biword_frequency,orient='index',columns=['frequency'])

# %%
word_pair_frequency = word_pair_frequency.reset_index()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/bn/y2jw2vgx5jj2qzmctncg36v80000gn/T/ipykernel_13458/2965482092.py in <module>
# ----> 1 _isna(None)
#
# /var/folders/bn/y2jw2vgx5jj2qzmctncg36v80000gn/T/ipykernel_13458/3018941083.py in <lambda>(x)
# ----> 1 _isna = lambda x: x.isna()
#
# AttributeError: 'NoneType' object has no attribute 'isna'

# %%
word_pair_frequency.insert(0,'word_1',word_pair_frequency['index'].map(lambda x: x.split('|')[0]))
word_pair_frequency.insert(1,'word_2',word_pair_frequency['index'].map(lambda x: x.split('|')[1]))

# %%
word_pair_frequency.head()
# Out:
#             word_1           word_2                   index  frequency
# 0             crow           please             crow|please          1
# 1           please  call.kin.in.law  please|call.kin.in.law          1
# 2  call.kin.in.law           NMLZ.A  call.kin.in.law|NMLZ.A          1
# 3           NMLZ.A            ocean            NMLZ.A|ocean          1
# 4            ocean       other.side        ocean|other.side          2

# %%
word_pair_frequency = word_pair_frequency.rename(columns={"index":'biword'})
word_pair_frequency.to_csv('../results/word_pair_frequency.tsv',sep='\t',index=None)

# %%
# Out:
# ['once.upon.a.time|man',
#  'man|all',
#  'all|be.two',
#  'be.two|EMP',
#  'EMP|be.born[3sbj.pass].',
#  'be.born[3sbj.pass].|all.the.time',
#  'woods|3POSS',
#  '3POSS|go',
#  'go|NMLZ.P.',
#  'NMLZ.P.|dog',
#  'PROG|OPT',
#  'OPT|hear.person',
#  'hear.person|3OBJ[1SBJ]',
#  '3OBJ[1SBJ]|DEF',
#  'DEF|chase',
#  'chase|NMLZ.INF',
#  'NMLZ.INF|3POSS.',
#  '3POSS.|all.the.time',
#  'PROG|hum',
#  'hum|NMLZ.INF.',
#  'NMLZ.INF.|DEM',
#  'DEM|PROG',
#  'PROG|so',
#  'so|do[3sbj]',
#  'do[3sbj]|woods',
#  'woods|relating.to',
#  'PROG|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|again.and.again',
#  'again.and.again|ITER',
#  'ITER|hum',
#  'hum|NMLZ.INF',
#  'OPT|hear.person',
#  'hear.person|3SOBJ[1SBJ].',
#  '3SOBJ[1SBJ].|PROG',
#  'PROG|go',
#  'go|3SBJ.DEF.',
#  '3NEG|be.far',
#  'be.far|go',
#  'go|3SBJ.DEF.',
#  '3SBJ.DEF.|UNK',
#  'UNK|look.back.every.few.steps',
#  'look.back.every.few.steps|3SBJ.DEF',
#  'EMPH|3NEG',
#  '3NEG|EMP',
#  'EMP|see',
#  'see|3SBJ.DEF',
#  '3SBJ.DEF|sibling',
#  'sibling|3POSS.',
#  'be.well|3NEG',
#  '3NEG|feel',
#  'feel|3SBJ.DEF.',
#  '3SBJ.DEF.|DEM',
#  'DEM|PST',
#  'PST|go.to',
#  'go.to|upright',
#  'upright|sit',
#  'sit|3SBJ.DEF.',
#  'tó|tol',
#  'tol|ił.',
#  'ił.|ko',
#  'ko|łowi',
#  'łowi|lág',
#  'lág|ił.',
#  'ił.|čuwowokós',
#  'ha|wél',
#  'wél|ił',
#  'ił|wóyic',
#  'wóyic|ha',
#  'ha|túw',
#  'túw|akw',
#  'akw|ahl',
#  'hi|no',
#  'no|kú',
#  'kú|to',
#  'to|wał',
#  'wał|tám',
#  'tám|ił.',
#  'ił.|čuwó',
#  'hih|kwi',
#  'kwi|d',
#  'd|átol',
#  'átol|ił.',
#  'ił.|hi',
#  'hi|ya',
#  'ya|wétw',
#  'wétw|ił.',
#  'ko|núk',
#  'núk|ak',
#  'ak|púšoth',
#  'púšoth|um',
#  'um|wóyic',
#  'hu|kówelaw',
#  'kówelaw|ekw',
#  'ekw|ahl.',
#  'ahl.|ku',
#  'ku|lúw',
#  'lúw|ił.',
#  'ił.|hi',
#  'hi|kú',
#  'kú|lag',
#  'lag|ił.',
#  'to|ku',
#  'ku|lúw',
#  'lúw|ił.',
#  'ił.|kwi',
#  'kwi|kú',
#  'kú|katow',
#  'katow|ił.',
#  'łkó|wi',
#  'wi|ye',
#  'ye|ko',
#  'ko|phł',
#  'phł|úih.',
#  'úih.|hi',
#  'hi|kó',
#  'kó|phł',
#  'phł|úih.',
#  'tówadákhad|ahl',
#  'ahl|hi',
#  'hi|túm',
#  'túm|ił',
#  'ko|la',
#  'la|wá',
#  'wá|gadútw',
#  'gadútw|ił.',
#  'ił.|kit',
#  'kit|ápal',
#  'ápal|uyh.',
#  'ku|thig',
#  'thig|átol',
#  'átol|ił.',
#  'ił.|kedú',
#  'kedú|to',
#  'to|ku',
#  'ku|tékwhłim.',
#  'wólok|ku',
#  'ku|ków',
#  'ków|adol',
#  'adol|wónokw',
#  'wo|kú',
#  'kú|lol.',
#  'lol.|čéčhočh',
#  'čéčhočh|hi',
#  'hi|níyab',
#  'níyab|áw',
#  'áw|ad.',
#  'ku|lág',
#  'lág|ił.',
#  'ił.|ku',
#  'ku|dawáłór',
#  'dawáłór|wónokw',
#  'bo|ku',
#  'ku|lól.',
#  'lól.|tełto',
#  'tełto|tó',
#  'tó|nagadak',
#  'wud|a',
#  'a|wóyic',
#  'wóyic|kí',
#  'kí|tokw',
#  'tokw|ił.',
#  'ił.|hi',
#  'hi|nóg',
#  'nóg|ił',
#  'kítko|ko',
#  'ko|ku',
#  'ku|lół',
#  'lół|ił.',
#  'ił.|kítko',
#  'kítko|hi',
#  'hi|kuc',
#  'kuc|étol',
#  'étol|ił.',
#  'ku|lúw',
#  'lúw|ił',
#  'ił|hi',
#  'hi|ku',
#  'ku|kwé',
#  'kwé|kł',
#  'kł|om',
#  'om|ił',
#  'hu|tokw.',
#  'tokw.|hi',
#  'hi|kú',
#  'kú|dawáłor',
#  'dawáłor|wónokw',
#  'bó|ku',
#  'ku|lol.',
#  'lol.|hí',
#  'hí|ku',
#  'ku|luh.',
#  'kwí|kł',
#  'kł|om',
#  'om|ił',
#  'ił|kud',
#  'kud|o',
#  'o|wóyic',
#  'to|tékwhłihm.',
#  'tékwhłihm.|kwi',
#  'kwi|kátow',
#  'kátow|ił.',
#  'ił.|hi',
#  'hi|kó',
#  'kó|pł',
#  'pł|úih.',
#  'ko|kátaw',
#  'kátaw|ił.',
#  'ił.|hi',
#  'hi|nók',
#  'nók|ił',
#  'šuwó|to',
#  'to|dákw',
#  'dákw|eh.',
#  'eh.|thíg',
#  'thíg|atol',
#  'atol|ił',
#  'ił|katow',
#  'katow|úlaw',
#  'úlaw|ił.',
#  'kit|án',
#  'án|aw',
#  'aw|ákw',
#  'ákw|ahl',
#  'ahl|čiwał',
#  'hi|kú',
#  'kú|wu',
#  'wu|thíg',
#  'thíg|atol',
#  'atol|ił.',
#  'ił.|hi',
#  'hi|nóg',
#  'nóg|ił',
#  'šuwa|to',
#  'to|dákwh',
#  'dákwh|eh',
#  'eh|łe',
#  'łe|kó',
#  'kó|la',
#  'la|bół',
#  'bół|ił.',
#  'hih|thig',
#  'thig|átol',
#  'átol|ił',
#  'ił|kháwoh',
#  'kháwoh|to',
#  'to|kátow',
#  'kátow|ił.',
#  'ko|la',
#  'la|lúwetw',
#  'lúwetw|ił.',
#  'ił.|hí',
#  'hí|dawáłor',
#  'dawáłor|thig',
#  'thig|átol',
#  'átol|ił.',
#  'mul|ókw',
#  'ókw|hi',
#  'hi|t',
#  't|átol',
#  'átol|ił',
#  'ił|łé',
#  'łé|ko',
#  'ko|la',
#  'la|wél',
#  'wél|ił.',
#  'kátow|ił',
#  'ił|ko',
#  'ko|la',
#  'la|wél',
#  'wél|uh.',
#  'uh.|hi',
#  'hi|tówíl',
#  'tówíl|im',
#  'im|ut',
#  'ut|ił',
#  'wew|ahl.',
#  'ahl.|hi',
#  'hi|yél',
#  'yél|ił',
#  'ił|kadá',
#  'kadá|la',
#  'la|wél',
#  'wél|ah.',
#  'ku|thig',
#  'thig|átol',
#  'átol|ił.',
#  'ił.|kowa',
#  'kowa|dáłak',
#  'dáłak|aw',
#  'aw|ił',
#  'ił|kítko.',
#  'kó|łowi',
#  'łowi|lág',
#  'lág|ił',
#  'ił|púšuk',
#  'púšuk|ił',
#  'ił|tó',
#  'tó|lekwhl',
#  'lekwhl|uh.',
#  'ko|łówi',
#  'łówi|lág',
#  'lág|ił',
#  'ił|hi',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił',
#  'ił|hu',
#  'hu|wéleł',
#  'wéleł|ahl.',
#  'ko|łówi',
#  'łówi|lág',
#  'lág|ił',
#  'ił|pušúk',
#  'pušúk|ił',
#  'ił|tó',
#  'tó|lekwhl',
#  'lekwhl|uh.',
#  'hi|kwe',
#  'kwe|kł',
#  'kł|óm',
#  'óm|ił',
#  'ił|hu',
#  'hu|tám',
#  'tám|ekw',
#  'ekw|ahl.',
#  'hís|tohl',
#  'tohl|ił',
#  'ił|tišk',
#  'tišk|óm',
#  'óm|aw',
#  'aw|ał',
#  'khú|wal',
#  'wal|ós',
#  'ós|ak.',
#  'ak.|kuc',
#  'kuc|kedó',
#  'kedó|lok',
#  'lok|ehl.',
#  'ehl.|čiwał',
#  'čiwał|kito',
#  'kúwil|wó',
#  'wó|ko',
#  'ko|lok',
#  'lok|a<h>n.',
#  'ho|kád',
#  'kád|tokw',
#  'tokw|á',
#  'á|kon',
#  'kon|aw',
#  'aw|eł',
#  'eł|il.',
#  'il.|čuwowałwáł',
#  'kalók|tol.',
#  'tol.|wónokw',
#  'wónokw|ko',
#  'ko|šu',
#  'šu|kú',
#  'kú|lol',
#  'lol|eh.',
#  'kówał|khi',
#  'khi|kú',
#  'kú|díyab',
#  'díyab|ob',
#  'ob|uhm.',
#  'šu|ku',
#  'ku|wátitw',
#  'wátitw|ów',
#  'ów|ar',
#  'ar|ag',
#  'ag|ko',
#  'ko|woł',
#  'khi|kú',
#  'kú|wał',
#  'wał|aw',
#  'aw|eg.',
#  'eg.|ku',
#  'ku|lóg',
#  'lóg|it',
#  'it|kítko.',
#  'hi|kú',
#  'kú|lág',
#  'lág|ił.',
#  'ił.|wónokw',
#  'wónokw|kó',
#  'kó|ku',
#  'ku|lol',
#  'lol|ił.',
#  'tełto|tó',
#  'tó|nágadak',
#  'nágadak|wónokw',
#  'wónokw|hí',
#  'hí|wo',
#  'wo|ku',
#  'ku|lól',
#  'lól|ił.',
#  'łé|ko',
#  'ko|lo',
#  'lo|wél',
#  'wél|ił.',
#  'ił.|ku',
#  'ku|lág',
#  'lág|ił.',
#  'kó|ku',
#  'ku|lol',
#  'lol|ił.',
#  'ił.|bew',
#  'bew|i',
#  'i|kulókh',
#  'kulókh|awel',
#  'awel|uyh',
#  'tó|gadel',
#  'gadel|hí',
#  'hí|ya',
#  'ya|bótok.',
#  'bótok.|kalákh',
#  'kalákh|a',
#  'a|lol',
#  'lol|ił.',
#  'tełto|tó',
#  'tó|nagadak',
#  'nagadak|bó',
#  'bó|ku',
#  'ku|lol',
#  'lol|kítko.',
#  'ku|kó',
#  'kó|la',
#  'la|wél',
#  'wél|ił.',
#  'ił.|ku',
#  'ku|lág',
#  'lág|ił.',
#  'khúno|ku',
#  'ku|liyo',
#  'liyo|kalók',
#  'kalók|tokw',
#  'tokw|hi',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił',
#  'tó|gadel',
#  'gadel|hi',
#  'hi|kowo',
#  'kowo|wótog.',
#  'wótog.|dónotwulúyuket',
#  'hi|y',
#  'y|etháw',
#  'etháw|onihl',
#  'onihl|lág',
#  'lág|ił',
#  'ił|kítko.',
#  'wo|lóg',
#  'lóg|ethám',
#  'ethám|ut',
#  'ut|at.',
#  'at.|hi',
#  'hi|wa',
#  'wa|lóg',
#  'lóg|ił',
#  'thám|ut',
#  'ut|ił.',
#  'ił.|to',
#  'to|lił',
#  'lił|élot',
#  'élot|ko',
#  'ko|wólokw',
#  'šuhdiyó|gálew',
#  'gálew|et.',
#  'et.|kú',
#  'kú|lág',
#  'lág|ił.',
#  'tó|ku',
#  'ku|lúw',
#  'lúw|ił.',
#  'ił.|yo',
#  'yo|kósw',
#  'kósw|a',
#  'a|sísw',
#  'sísw|ek',
#  'hawégadak|hi',
#  'hi|łák',
#  'łák|ulaw',
#  'ulaw|ónihl.',
#  'łák|u',
#  'u|wis',
#  'wis|ónihl.',
#  'ónihl.|kówa',
#  'kówa|dawáłor',
#  'šudiyó|galaw',
#  'galaw|ił.',
#  'ił.|hi',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił',
#  'sisw|ágadak.',
#  'ágadak.|hi',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił',
#  'ił|hi',
#  'hi|ta',
#  'ta|wés',
#  'wés|onihl.',
#  'hi|łág',
#  'łág|ił.',
#  'ił.|hí',
#  'hí|ta',
#  'ta|l',
#  'l|ab',
#  'ab|út',
#  'út|ił.',
#  'tó|wi',
#  'wi|kł',
#  'kł|óm',
#  'óm|ił.',
#  'ił.|hi',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił',
#  'ił|hawégadak.',
#  'ku|lág',
#  'lág|ił.',
#  'ił.|tó',
#  'tó|ku',
#  'ku|lúw',
#  'lúw|ił.',
#  'ił.|hi',
#  'hi|nóg',
#  'nóg|ił',
#  'bo|wałé',
#  'wałé|ku',
#  'ku|lol',
#  'lol|kítko.',
#  'kítko.|ko',
#  'ko|łowi',
#  'łowi|lág',
#  'lág|ił.',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił',
#  'ił|mélakw',
#  'mélakw|ha',
#  'ha|wéleł',
#  'wéleł|ahl.',
#  'ahl.|khúno',
#  'tokátkotágadak|či',
#  'či|tokt',
#  'tokt|ho',
#  'ho|kós',
#  'hih|duw',
#  'duw|ił.',
#  'ił.|tó',
#  'tó|tol',
#  'tol|ił.',
#  'ił.|mélakw',
#  'hi|ya',
#  'ya|wél',
#  'wél|ił.',
#  'ił.|łe',
#  'łe|kó',
#  'kó|soból',
#  'soból|ew',
#  'ew|ił.',
#  'tó|tol',
#  'tol|ił.',
#  'ił.|ko',
#  'ko|łówi',
#  'łówi|lág',
#  'lág|ił.',
#  'ił.|kwołwał',
#  'hi|kú',
#  'kú|wél',
#  'wél|ił',
#  'ił|mélakw.',
#  'łe|ko',
#  'ko|soból',
#  'soból|ew',
#  'ew|ił.',
#  'kwi|thig',
#  'thig|átol',
#  'átol|ił',
#  'ił|bómel',
#  'bómel|aw',
#  'aw|ókw.',
#  'kwi|kł',
#  'kł|óm',
#  'óm|ił',
#  'ił|čečhóčh',
#  'čečhóčh|tu',
#  'tu|mige',
#  'mige|sísw',
#  'sísw|apt',
#  'tu|mige',
#  'mige|balúyab',
#  'balúyab|apt',
#  'apt|hu',
#  'hu|madón',
#  'madón|ahl',
#  'tu|šuyag',
#  'šuyag|íth',
#  'íth|ad.',
#  'ad.|bokos',
#  'bokos|hi',
#  'hi|swól',
#  'swól|ew',
#  'ew|ił.',
#  'hi|níyab',
#  'níyab|úm',
#  'úm|ił.',
#  'ił.|th',
#  'th|óm',
#  'óm|ił.',
#  'ił.|hi',
#  'hi|yákw',
#  'th|ab',
#  'ab|ił.',
#  'ił.|kówo',
#  'kówo|púw',
#  'púw|ił.',
#  'ił.|hi',
#  'hi|rú',
#  'rú|lap.',
#  'kó|phł',
#  'phł|ił.',
#  'ił.|kit',
#  'kit|ápal',
#  'ápal|akw',
#  'akw|ahl',
#  'ku|kikátol',
#  'kikátol|ił.',
#  'ił.|to',
#  'to|ku',
#  'ku|lúw',
#  'lúw|ił.',
#  'ił.|kič',
#  'hił|hi',
#  'hi|lócuw',
#  'lócuw|ił.']

# %%
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0           NaN     Kwétow         ił    carórił        kuc          o
# 1           NaN   Long.ago   3SBJ.DEF       girl     be.one        EMP
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN    Čuwowáł       kówa        dár         ił  hawegádak
# 4           NaN        DEM       INCH      do.so   3SBJ.DEF      grass
# ..          ...        ...        ...        ...        ...        ...
# 207         NaN         Ko         ku         tu   dódatkhš        ił.
# 208         NaN       3NEG       ITER         PL       move  3SBJ.DEF.
# 209         NaN        NaN        NaN        NaN        NaN        NaN
# 210         NaN         ku         tu        lág         ey        oth
# 211         NaN       ITER         PL         go    TH.CAUS       CAUS
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0           ki       łákw         iw        ił.         NaN         NaN
# 1         CESS       grow       REFL  3SBJ.DEF.         NaN         NaN
# 2          NaN        NaN        NaN        NaN         NaN         NaN
# 3          NaN        NaN        NaN        NaN         NaN         NaN
# 4          NaN        NaN        NaN        NaN         NaN         NaN
# ..         ...        ...        ...        ...         ...         ...
# 207       Kówa       khun         od  čuwatokos         NaN         NaN
# 208       INCH   get.dark   3SBJ.STV        DEM         NaN         NaN
# 209        NaN        NaN        NaN        NaN         NaN         NaN
# 210         um        ił.        NaN        NaN         NaN         NaN
# 211       3OBJ  3SBJ.DEF.        NaN        NaN         NaN         NaN
#
# [212 rows x 12 columns]

# %%
'á|kon' in reichard_wordpairs
# Out:
# True

# %%
random.sample(reichard_wordpairs,20)
# Out:
# ['lág|ił.',
#  'PST|go',
#  'ITER|go',
#  'INDF|only[1poss]',
#  '3OBJ|1SBJ',
#  'PST|accompany',
#  'bó|ku',
#  'go|3SBJ.DEF.',
#  '3OBJ|CAUS',
#  'all.the.time|1POSS',
#  '3SBJ.DEF|PST',
#  'PL|sit',
#  '3OBJ|3SBJ.INDF.',
#  'PFV|suck',
#  'surely|around',
#  'win|TH.IMPL.',
#  'INCH|think.about',
#  'PROG|ITER',
#  'INCH|think.about',
#  '3POSS|tracks']
